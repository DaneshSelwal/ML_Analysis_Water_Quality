# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Uninstall existing scikit-learn to avoid conflicts
# !pip uninstall -y scikit-learn
# Install specific versions of libraries to avoid conflicts
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization
# !pip install optuna
# !pip install gpboost
# !pip install shap
# !pip install ngboost
# !pip install dask[dataframe]
# !pip install torch seaborn
# !pip install lightgbm
# !pip install xgboost
# !pip install lime
# !pip install interpret
# !pip install optunahub
# !pip install cmaes
# !pip install plotly kaleido
# !pip install openpyxl
# !pip install -U kaleido
# !pip install properscoring
# !pip install XlsxWriter
# !pip install cython
# !pip install pgbm
# !pip install torch
# !pip install cp
# !pip install mapie
# !pip install torch skorch puncc
# Reinstall scikit-learn to the version required by ngboost
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Reinstall numpy first
# !pip install numpy==1.26.4  # Use the version compatible with catboost
# Reinstall catboost
# !pip install catboost
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.5.2
#   Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ngboost 0.5.6 requires scikit-learn<2.0,>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.6.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: gpboost in /usr/local/lib/python3.11/dist-packages (1.5.8)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from gpboost) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from gpboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.15.3)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from gpboost) (4.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->gpboost) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->gpboost) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->gpboost) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->gpboost) (3.2.2)
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.13.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: ngboost in /usr/local/lib/python3.11/dist-packages (0.5.6)
# Requirement already satisfied: lifelines>=0.25 in /usr/local/lib/python3.11/dist-packages (from ngboost) (0.30.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.26.4)
# Collecting scikit-learn<2.0,>=1.6 (from ngboost)
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.15.3)
# Requirement already satisfied: tqdm>=4.3 in /usr/local/lib/python3.11/dist-packages (from ngboost) (4.67.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.1.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (3.6.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines>=0.25->ngboost) (1.17.0)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed scikit-learn-1.6.1
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.12.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.2.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.7.0)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.21)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.3)
# Requirement already satisfied: lime in /usr/local/lib/python3.11/dist-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.5.10)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Requirement already satisfied: interpret in /usr/local/lib/python3.11/dist-packages (0.6.10)
# Requirement already satisfied: interpret-core==0.6.10 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.6.10)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.26.4)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.5.0)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.9.5)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.17.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.24.1)
# Requirement already satisfied: SALib>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.5.1)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.47.2)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.3.7)
# Requirement already satisfied: aplr>=10.6.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (10.9.0)
# Requirement already satisfied: dash<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.18.2)
# Requirement already satisfied: dash-core-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.0.0)
# Requirement already satisfied: dash-html-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.0.0)
# Requirement already satisfied: dash-table>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.0.0)
# Requirement already satisfied: dash-cytoscape>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.0.2)
# Requirement already satisfied: gevent>=1.3.6 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (25.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.32.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.13.2)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (75.2.0)
# Requirement already satisfied: greenlet>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.2.2)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (7.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (24.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (9.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.4.26)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.10.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.70.15)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18.1->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (8.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.2.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.3.8)
# Requirement already satisfied: optunahub in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: ga4mp in /usr/local/lib/python3.11/dist-packages (from optunahub) (2.0.4)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optunahub) (4.3.0)
# Requirement already satisfied: PyGithub>=1.59 in /usr/local/lib/python3.11/dist-packages (from optunahub) (2.6.1)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (4.13.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.4.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (1.2.18)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optunahub) (1.1.3)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->PyGithub>=1.59->optunahub) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optunahub) (3.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->PyGithub>=1.59->optunahub) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub>=1.59->optunahub) (2.22)
# Requirement already satisfied: cmaes in /usr/local/lib/python3.11/dist-packages (0.11.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cmaes) (1.26.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: properscoring in /usr/local/lib/python3.11/dist-packages (0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.15.3)
# Requirement already satisfied: XlsxWriter in /usr/local/lib/python3.11/dist-packages (3.2.3)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Requirement already satisfied: pgbm in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pgbm) (1.6.1)
# Requirement already satisfied: ninja>=1.10.2.2 in /usr/local/lib/python3.11/dist-packages (from pgbm) (1.11.1.4)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.11/dist-packages (from pgbm) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (3.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: cp in /usr/local/lib/python3.11/dist-packages (2020.12.3)
# Requirement already satisfied: mapie in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.11/dist-packages (from mapie) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mapie) (1.15.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from mapie) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapie) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapie) (3.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: skorch in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: puncc in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.15.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from puncc) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from puncc) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from puncc) (2.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.0->skorch) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->puncc) (1.17.0)
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.6.1
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)

# %%
# Restart the runtime to apply changes
import os
os._exit(00)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu124/split_decision...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/split_decision/build.ninja...
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module split_decision...
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
train_data_path = "./drive/MyDrive/WATER QUALITY/WQI_uncertainity/train.csv"
test_data_path = "./drive/MyDrive/WATER QUALITY/WQI_uncertainity/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (190, 152)
# First 5 rows of training data:
#         R1      R2      R3      R4      R5      R6      R7      R8      R9  \
# 0  3.5960  3.6080  3.0100  3.6130  3.3760  2.2780  1.3410  3.4570  3.3540
# 1  2.9540  3.0470  3.1160  4.2640  4.4090  3.4810  2.3760  3.4030  3.4320
# 2  2.4870  2.9430  2.5290  3.7280  2.9870  1.8890  1.9960  2.1020  1.6180
# 3  1.3640  1.4186  1.3789  1.4776  1.5063  1.4047  1.2648  1.5166  1.5443
# 4  1.3074  1.3820  1.3476  1.3986  1.3403  1.3004  1.3719  1.3984  1.3865
#
#       R10  ...    R143    R144    R145    R146    R147   R148    R149    R150  \
# 0  1.9900  ...  2.7930  1.9660  2.3070  1.5280  1.9380  3.371  2.2060  1.5220
# 1  2.6350  ...  3.0260  2.3530  2.0400  1.7400  2.6250  4.026  2.9010  1.7450
# 2  1.2720  ...  1.2760  1.5990  1.8610  1.0290  1.8690  3.905  2.3200  1.3310
# 3  1.3834  ...  1.2223  1.0919  1.0995  1.0856  1.1728  1.315  1.2341  1.0753
# 4  1.3964  ...  1.1691  1.0689  1.1230  1.1384  1.1810  1.235  1.1589  1.1013
#
#      R151  WQI
# 0  1.7780  333
# 1  1.8710  222
# 2  1.2180  212
# 3  0.9929  116
# 4  1.0892  111
#
# [5 rows x 152 columns]
#
# Shape of test data: (82, 152)
# First 5 rows of test data:
#         R1      R2      R3      R4      R5      R6      R7     R8      R9  \
# 0  4.5531  4.5227  4.3613  4.3948  4.3138  4.2704  4.4091  4.663  4.5893
# 1  3.1470  3.2270  1.9290  2.3130  2.5630  1.6990  0.1830  1.843  3.0820
# 2  6.8500  6.5500  6.1280  8.1530  7.4810  6.2120  6.6030  7.440  7.4990
#   -3.13666700e-01 -5.80223396e-01 -4.30185817e-01  1.09917264e-01
#   -5.00027960e-01 -8.94606238e-01 -7.79152416e-01 -6.40829553e-01
#   -1.26929466e+00 -1.48599708e+00 -1.01823513e+00 -6.97472529e-01
#   -6.55763689e-01 -8.40583611e-01 -1.04437714e+00 -9.29187637e-01
#   -8.46905331e-01 -1.04592270e+00 -1.59149083e+00 -1.49515363e+00
#   -1.04540431e+00 -7.01172725e-01 -6.59050982e-01 -5.16317785e-01
#   -5.83049433e-01 -1.01207570e+00 -9.93874355e-01 -9.83537348e-01
#   -9.50177764e-01 -7.53505381e-01 -6.85568795e-01 -6.03045991e-01
#   -4.04272414e-01 -3.63160453e-01 -4.46856467e-01 -6.98607028e-01
#   -1.09395583e+00 -9.67994562e-01 -6.28412852e-01 -3.32431339e-01
#   -4.10979349e-01 -5.40805904e-01 -5.79540664e-01 -5.04743920e-01
#   -7.00121417e-01 -5.34311672e-01 -3.81162536e-01 -1.15678397e+00
#   -1.19197298e+00 -8.82239880e-01 -6.69349623e-01 -3.04809858e-01
#   -1.11312749e+00 -1.69709766e+00 -4.95045563e-01 -7.12527408e-01
#   -1.38572549e+00 -1.06895771e+00 -1.53308202e+00 -8.73020289e-01
#   -8.52478054e-01 -1.60261085e+00 -8.36230728e-01 -3.47691934e-01
#   -4.39048629e-01 -6.21093673e-01 -4.55704793e-01 -6.24058928e-01
#   -1.33811014e+00 -1.01745165e+00 -3.83831978e-01 -3.59281584e-01
#   -1.03304982e+00 -8.70828456e-01 -5.64603026e-01 -5.59323372e-01
#   -9.50369133e-01 -6.35271509e-01 -1.36860048e-01]]

# %%
# Define the model classes
model_classes = {
    'Random Forest': RandomForestRegressor,
    'Gradient Boosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'LightGBM': LGBMRegressor,
    'GPBoost': GPBoostRegressor,
    'CatBoost': CatBoostRegressor,
    'NGBoost': NGBRegressor
}

feature_names = [f'R{i}' for i in range(1, 152)]

# %%
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    plt.savefig(rmse_image_path)
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    plt.savefig(corr_image_path)
    plt.close()

    # Load the existing Excel file
    workbook = load_workbook(excel_file_path)

    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    workbook.save(excel_file_path)

    # Clean up the image files
    os.remove(rmse_image_path)
    os.remove(corr_image_path)

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = model_info['best_params']
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        model = model_class(**best_params)
        model.fit(X_train, y_train)

        def predict_fn(data):
            return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)

        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)

        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            continue

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(image_path)
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            workbook = load_workbook(excel_file_path)
            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores
            scores_sheet.append(['Feature', 'SHAP Importance'])
            for feature, importance in feature_importances_shap.items():
                scores_sheet.append([feature, importance])

            # Save the workbook
            workbook.save(excel_file_path)

            # Clean up the image file
            os.remove(image_path)

# %% [markdown]
# # **Autosampler by Optuna**

# %%
# Suppress Optuna's verbose output
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Define objective and metric functions for PGBM
def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss

def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {}) # PGBM is handled separately
    }


    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})

    for model_name, (model_class, param_space) in models.items():
        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            try:
                sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
                study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

                if model_name == 'PGBM':
                    def pgbm_objective(trial):
                        params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                        model = PGBM()
                        model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=params)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(pgbm_objective, n_trials=50)
                else:
                    def objective(trial, model_name, model_class, param_space):
                        params = {}
                        for key, values in param_space.items():
                            if isinstance(values, list):
                                params[key] = trial.suggest_categorical(key, values)
                            elif isinstance(values, tuple):
                                if len(values) == 2:
                                    params[key] = trial.suggest_float(key, values[0], values[1])
                                elif len(values) == 3 and isinstance(values[2], bool) and values[2]:
                                    params[key] = trial.suggest_int(key, values[0], values[1])
                                else:
                                    raise ValueError(f"Invalid parameter range for {key}")

                        model = model_class(**params)
                        model.fit(X_train, y_train)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(lambda trial: objective(trial, model_name, model_class, param_space), n_trials=50)

                best_params = study.best_params
                best_model = model_class(**best_params) if model_name != 'PGBM' else PGBM()
                if model_name == 'PGBM':
                    best_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
                else:
                    best_model.fit(X_train, y_train)
                y_pred = best_model.predict(X_test)

                mse = mean_squared_error(y_test, y_pred)
                rmse = np.sqrt(mse)
                corr_coef = np.corrcoef(y_test, y_pred)[0, 1]

                # Save predictions to DataFrame
                predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

                best_scores[(model_name, pruner_name)] = {
                    'best_score': mse,
                    'best_params': best_params,
                    'test_mse': mse,
                    'test_rmse': rmse,
                    'test_corr_coef': corr_coef,
                    'pruner': pruner_name
                }
                print(f"Best MSE for {model_name} with {pruner_name}: {mse} with params: {best_params}")
                print(f"Best RMSE for {model_name} with {pruner_name}: {rmse}")
                print(f"Correlation Coefficient for {model_name} with {pruner_name}: {corr_coef}")
            except Exception as e:
                print(f"Failed to run Optuna for {model_name} with {pruner_name}. Error: {e}")

    # Write predictions to Excel
    with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a') as writer:
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)

    if best_scores:
        best_model_name, best_pruner_name = min(best_scores, key=lambda k: best_scores[k]['test_mse'])
        best_model_info = best_scores[(best_model_name, best_pruner_name)]
        print(f"\nBest model on test data: {best_model_name} with {best_pruner_name}")
        print(f"Test MSE: {best_model_info['test_mse']}")
        print(f"Test RMSE: {best_model_info['test_rmse']}")
        print(f"Correlation Coefficient: {best_model_info['test_corr_coef']}")
        print(f"Best Parameters: {best_model_info['best_params']}")
        print(f"Pruner Used: {best_model_info['pruner']}")
    else:
        print("No valid model configurations found.")

    return best_scores

# Example usage
best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/WATER QUALITY/WQI_uncertainity/WQI_ml/HyperParameter_Tuning/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# Best MSE for Random Forest with MedianPruner: 926.9746881386717 with params: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with MedianPruner: 30.446259017138242
# Correlation Coefficient for Random Forest with MedianPruner: 0.9380539187700511
# Running Optuna for Random Forest with NopPruner...
# Best MSE for Random Forest with NopPruner: 937.9560207935197 with params: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}
# Best RMSE for Random Forest with NopPruner: 30.62606766781396
# Correlation Coefficient for Random Forest with NopPruner: 0.9338201932833533
# Running Optuna for Random Forest with PatientPruner...
# Best MSE for Random Forest with PatientPruner: 928.3935142510413 with params: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}
# Best RMSE for Random Forest with PatientPruner: 30.469550607960095
# Correlation Coefficient for Random Forest with PatientPruner: 0.9318269362838447
# Running Optuna for Random Forest with PercentilePruner...
# Best MSE for Random Forest with PercentilePruner: 936.3276968392234 with params: {'n_estimators': 700, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with PercentilePruner: 30.599472166023116
# Correlation Coefficient for Random Forest with PercentilePruner: 0.9443155093176682
# Running Optuna for Random Forest with SuccessiveHalvingPruner...
# Best MSE for Random Forest with SuccessiveHalvingPruner: 922.9224466496914 with params: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with SuccessiveHalvingPruner: 30.379638685305185
# Correlation Coefficient for Random Forest with SuccessiveHalvingPruner: 0.9344935993588843
# Running Optuna for Random Forest with HyperbandPruner...
# Best MSE for Random Forest with HyperbandPruner: 928.6979037649045 with params: {'n_estimators': 200, 'criterion': 'squared_error', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}
# Best RMSE for Random Forest with HyperbandPruner: 30.474545177326345
# Correlation Coefficient for Random Forest with HyperbandPruner: 0.9305524100852461
# Running Optuna for Random Forest with ThresholdPruner...
# Best MSE for Random Forest with ThresholdPruner: 929.8587794201471 with params: {'n_estimators': 200, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with ThresholdPruner: 30.49358587342832
# Correlation Coefficient for Random Forest with ThresholdPruner: 0.930542178541985
# Running Optuna for Random Forest with WilcoxonPruner...
# Best MSE for Random Forest with WilcoxonPruner: 928.8038145612356 with params: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.3, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}
# Best RMSE for Random Forest with WilcoxonPruner: 30.476282820600606
# Correlation Coefficient for Random Forest with WilcoxonPruner: 0.931846820097067
# Running Optuna for Gradient Boosting with MedianPruner...
# Best MSE for Gradient Boosting with MedianPruner: 826.8450802541028 with params: {'loss': 'squared_error', 'learning_rate': 0.2, 'n_estimators': 100, 'subsample': 0.5, 'criterion': 'squared_error', 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.1, 'max_depth': 10, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with MedianPruner: 28.754914019243785
# Correlation Coefficient for Gradient Boosting with MedianPruner: 0.9279449171502246
# Running Optuna for Gradient Boosting with NopPruner...
# Best MSE for Gradient Boosting with NopPruner: 781.7895087976207 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'criterion': 'squared_error', 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_depth': 10, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 'sqrt', 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 20, 'tol': 0.0001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with NopPruner: 27.96049907990951
# Correlation Coefficient for Gradient Boosting with NopPruner: 0.9341384925660862
# Running Optuna for Gradient Boosting with PatientPruner...
# Best MSE for Gradient Boosting with PatientPruner: 668.5962917226813 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.5, 'criterion': 'squared_error', 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_depth': 3, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 'sqrt', 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'tol': 0.001, 'ccp_alpha': 0.01}
# Best RMSE for Gradient Boosting with PatientPruner: 25.857229003175906
# Correlation Coefficient for Gradient Boosting with PatientPruner: 0.9420302992631479
# Running Optuna for Gradient Boosting with PercentilePruner...
# Best MSE for Gradient Boosting with PercentilePruner: 696.7060074905164 with params: {'loss': 'huber', 'learning_rate': 0.2, 'n_estimators': 500, 'subsample': 0.5, 'criterion': 'friedman_mse', 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_depth': 3, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': 10, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with PercentilePruner: 26.395189097457067
# Correlation Coefficient for Gradient Boosting with PercentilePruner: 0.946479542303648
# Running Optuna for Gradient Boosting with SuccessiveHalvingPruner...
# Best MSE for Gradient Boosting with SuccessiveHalvingPruner: 771.7055331834227 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 300, 'subsample': 0.5, 'criterion': 'squared_error', 'min_samples_split': 0.01, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_depth': 10, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with SuccessiveHalvingPruner: 27.779588427178375
# Correlation Coefficient for Gradient Boosting with SuccessiveHalvingPruner: 0.9441148112370387
# Running Optuna for Gradient Boosting with HyperbandPruner...
# Best MSE for Gradient Boosting with HyperbandPruner: 702.5066063040902 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.5, 'criterion': 'squared_error', 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_depth': 10, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 'sqrt', 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 50, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.01}
# Best RMSE for Gradient Boosting with HyperbandPruner: 26.504841186169937
# Correlation Coefficient for Gradient Boosting with HyperbandPruner: 0.9410771823195679
# Running Optuna for Gradient Boosting with ThresholdPruner...
# Best MSE for Gradient Boosting with ThresholdPruner: 716.4136543206561 with params: {'loss': 'absolute_error', 'learning_rate': 0.2, 'n_estimators': 200, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_depth': 5, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.01}
# Best RMSE for Gradient Boosting with ThresholdPruner: 26.765904698340687
# Correlation Coefficient for Gradient Boosting with ThresholdPruner: 0.9402314074316714
# Running Optuna for Gradient Boosting with WilcoxonPruner...
# Best MSE for Gradient Boosting with WilcoxonPruner: 727.7486334239142 with params: {'loss': 'absolute_error', 'learning_rate': 0.1, 'n_estimators': 500, 'subsample': 1.0, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_depth': 5, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 'sqrt', 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 10, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with WilcoxonPruner: 26.976816591731392
# Correlation Coefficient for Gradient Boosting with WilcoxonPruner: 0.9360999910400127
# Running Optuna for XGBoost with MedianPruner...
# Best MSE for XGBoost with MedianPruner: 690.8297729492188 with params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.5, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.7, 'reg_alpha': 1, 'reg_lambda': 1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with MedianPruner: 26.283640785652562
# Correlation Coefficient for XGBoost with MedianPruner: 0.9457246603165833
# Running Optuna for XGBoost with NopPruner...
# Best MSE for XGBoost with NopPruner: 686.6576538085938 with params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.5, 'reg_alpha': 0.01, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with NopPruner: 26.204153369429697
# Correlation Coefficient for XGBoost with NopPruner: 0.9497348647658967
# Running Optuna for XGBoost with PatientPruner...
# Best MSE for XGBoost with PatientPruner: 622.8858642578125 with params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'gamma': 0.5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.9, 'reg_alpha': 1, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PatientPruner: 24.957681467993226
# Correlation Coefficient for XGBoost with PatientPruner: 0.9526383255315664
# Running Optuna for XGBoost with PercentilePruner...
# Best MSE for XGBoost with PercentilePruner: 605.669677734375 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 7, 'min_child_weight': 3, 'gamma': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.7, 'reg_alpha': 0, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PercentilePruner: 24.61035712325961
# Correlation Coefficient for XGBoost with PercentilePruner: 0.9508572219911771
# Running Optuna for XGBoost with SuccessiveHalvingPruner...
# Best MSE for XGBoost with SuccessiveHalvingPruner: 654.443603515625 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 3, 'min_child_weight': 5, 'gamma': 0.5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.7, 'reg_alpha': 1, 'reg_lambda': 10, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with SuccessiveHalvingPruner: 25.58209536991888
# Correlation Coefficient for XGBoost with SuccessiveHalvingPruner: 0.9481971540163014
# Running Optuna for XGBoost with HyperbandPruner...
# Best MSE for XGBoost with HyperbandPruner: 664.0693359375 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.5, 'subsample': 0.9, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.5, 'reg_alpha': 0.01, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with HyperbandPruner: 25.769542796438976
# Correlation Coefficient for XGBoost with HyperbandPruner: 0.9473404883534584
# Running Optuna for XGBoost with ThresholdPruner...
# Best MSE for XGBoost with ThresholdPruner: 687.9976806640625 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.7, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.5, 'reg_alpha': 0.01, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with ThresholdPruner: 26.229709885243917
# Correlation Coefficient for XGBoost with ThresholdPruner: 0.9493622590036852
# Running Optuna for XGBoost with WilcoxonPruner...
# Best MSE for XGBoost with WilcoxonPruner: 690.7450561523438 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0, 'subsample': 0.5, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.7, 'reg_alpha': 0, 'reg_lambda': 5, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with WilcoxonPruner: 26.28202914830481
# Correlation Coefficient for XGBoost with WilcoxonPruner: 0.9434444285701333
# Running Optuna for LightGBM with MedianPruner...
# Best MSE for LightGBM with MedianPruner: 687.6213685241634 with params: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 0.01, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with MedianPruner: 26.22253550906478
# Correlation Coefficient for LightGBM with MedianPruner: 0.9486948872823441
# Running Optuna for LightGBM with NopPruner...
# Best MSE for LightGBM with NopPruner: 748.6190203392741 with params: {'n_estimators': 500, 'learning_rate': 0.1, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 10, 'min_child_weight': 0.001, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with NopPruner: 27.360903134569117
# Correlation Coefficient for LightGBM with NopPruner: 0.9450914571670231
# Running Optuna for LightGBM with PatientPruner...
# Best MSE for LightGBM with PatientPruner: 707.208125570096 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'num_leaves': 15, 'max_depth': -1, 'min_child_samples': 10, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 10, 'min_child_weight': 1e-05, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PatientPruner: 26.59338499646286
# Correlation Coefficient for LightGBM with PatientPruner: 0.9407200289406664
# Running Optuna for LightGBM with PercentilePruner...
# Best MSE for LightGBM with PercentilePruner: 766.6062716200108 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'num_leaves': 63, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.5, 'reg_alpha': 0.01, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'bagging_freq': 0, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PercentilePruner: 27.687655581865556
# Correlation Coefficient for LightGBM with PercentilePruner: 0.9345182922130101
# Running Optuna for LightGBM with SuccessiveHalvingPruner...
# Best MSE for LightGBM with SuccessiveHalvingPruner: 587.9233862763272 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'num_leaves': 15, 'max_depth': 5, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with SuccessiveHalvingPruner: 24.247131506145777
# Correlation Coefficient for LightGBM with SuccessiveHalvingPruner: 0.9577393597234097
# Running Optuna for LightGBM with HyperbandPruner...
# Best MSE for LightGBM with HyperbandPruner: 598.7971005905614 with params: {'n_estimators': 200, 'learning_rate': 0.15, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0.01, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with HyperbandPruner: 24.470331027400537
# Correlation Coefficient for LightGBM with HyperbandPruner: 0.9562046162750685
# Running Optuna for LightGBM with ThresholdPruner...
# Best MSE for LightGBM with ThresholdPruner: 673.6967643304616 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0, 'reg_lambda': 10, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with ThresholdPruner: 25.95566921368936
# Correlation Coefficient for LightGBM with ThresholdPruner: 0.9502168225063722
# Running Optuna for LightGBM with WilcoxonPruner...
# Best MSE for LightGBM with WilcoxonPruner: 727.0376394439177 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'num_leaves': 63, 'max_depth': 7, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'reg_lambda': 0.1, 'min_child_weight': 0.01, 'bagging_freq': 0, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with WilcoxonPruner: 26.96363550124348
# Correlation Coefficient for LightGBM with WilcoxonPruner: 0.9387415382908113
# Running Optuna for GPBoost with MedianPruner...
# Best MSE for GPBoost with MedianPruner: 705.2209234493985 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 5, 'num_leaves': 31, 'min_child_samples': 20, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0, 'reg_lambda': 0.5, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with MedianPruner: 26.555995998067903
# Correlation Coefficient for GPBoost with MedianPruner: 0.9409981493259966
# Running Optuna for GPBoost with NopPruner...
# Best MSE for GPBoost with NopPruner: 701.3000437709593 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 5, 'num_leaves': 31, 'min_child_samples': 20, 'subsample': 0.7, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0.5, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with NopPruner: 26.48207023196939
# Correlation Coefficient for GPBoost with NopPruner: 0.9415580579884352
# Running Optuna for GPBoost with PatientPruner...
# Best MSE for GPBoost with PatientPruner: 758.8116327218879 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 63, 'min_child_samples': 20, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 1.0, 'reg_lambda': 0.1, 'min_child_weight': 0.1, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PatientPruner: 27.546535766260845
# Correlation Coefficient for GPBoost with PatientPruner: 0.935366184889031
# Running Optuna for GPBoost with PercentilePruner...
# Best MSE for GPBoost with PercentilePruner: 749.6043356730718 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'max_depth': 5, 'num_leaves': 63, 'min_child_samples': 20, 'subsample': 0.5, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 0, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PercentilePruner: 27.378903113037087
# Correlation Coefficient for GPBoost with PercentilePruner: 0.9369245701596264
# Running Optuna for GPBoost with SuccessiveHalvingPruner...
# Best MSE for GPBoost with SuccessiveHalvingPruner: 715.7122947830827 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 5, 'num_leaves': 63, 'min_child_samples': 20, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 0.5, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with SuccessiveHalvingPruner: 26.752799755971015
# Correlation Coefficient for GPBoost with SuccessiveHalvingPruner: 0.9406035271489431
# Running Optuna for GPBoost with HyperbandPruner...
# Best MSE for GPBoost with HyperbandPruner: 729.821365222223 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': -1, 'num_leaves': 31, 'min_child_samples': 20, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with HyperbandPruner: 27.01520618507701
# Correlation Coefficient for GPBoost with HyperbandPruner: 0.9371427391264351
# Running Optuna for GPBoost with ThresholdPruner...
# Best MSE for GPBoost with ThresholdPruner: 713.8617694748239 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'max_depth': 5, 'num_leaves': 31, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.5, 'reg_alpha': 0, 'reg_lambda': 1.0, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with ThresholdPruner: 26.71819173287788
# Correlation Coefficient for GPBoost with ThresholdPruner: 0.9389779348832684
# Running Optuna for GPBoost with WilcoxonPruner...
# Best MSE for GPBoost with WilcoxonPruner: 698.1615125042936 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 5, 'num_leaves': 63, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0.5, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with WilcoxonPruner: 26.422746119665412
# Correlation Coefficient for GPBoost with WilcoxonPruner: 0.9417902712966542
# Running Optuna for CatBoost with MedianPruner...
# Best MSE for CatBoost with MedianPruner: 624.6051161335615 with params: {'iterations': 1000, 'learning_rate': 0.03, 'depth': 4, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 1.0, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with MedianPruner: 24.992101074810847
# Correlation Coefficient for CatBoost with MedianPruner: 0.9533092119864104
# Running Optuna for CatBoost with NopPruner...
# Best MSE for CatBoost with NopPruner: 692.5096873387843 with params: {'iterations': 1000, 'learning_rate': 0.03, 'depth': 4, 'l2_leaf_reg': 1, 'border_count': 64, 'min_data_in_leaf': 10, 'rsm': 0.8, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with NopPruner: 26.315578795435684
# Correlation Coefficient for CatBoost with NopPruner: 0.9481648081163799
# Running Optuna for CatBoost with PatientPruner...
# Best MSE for CatBoost with PatientPruner: 615.3808191312761 with params: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 5, 'rsm': 0.8, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PatientPruner: 24.80687040179144
# Correlation Coefficient for CatBoost with PatientPruner: 0.9520973423458917
# Running Optuna for CatBoost with PercentilePruner...
# Best MSE for CatBoost with PercentilePruner: 630.5890782836616 with params: {'iterations': 500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 64, 'min_data_in_leaf': 5, 'rsm': 1.0, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PercentilePruner: 25.111532774477578
# Correlation Coefficient for CatBoost with PercentilePruner: 0.9489559729651481
# Running Optuna for CatBoost with SuccessiveHalvingPruner...
# Best MSE for CatBoost with SuccessiveHalvingPruner: 607.1987681378401 with params: {'iterations': 500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 64, 'min_data_in_leaf': 1, 'rsm': 0.6, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with SuccessiveHalvingPruner: 24.64140353425186
# Correlation Coefficient for CatBoost with SuccessiveHalvingPruner: 0.9532324332878932
# Running Optuna for CatBoost with HyperbandPruner...
# Best MSE for CatBoost with HyperbandPruner: 630.5890782836616 with params: {'iterations': 500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 64, 'min_data_in_leaf': 10, 'rsm': 1.0, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with HyperbandPruner: 25.111532774477578
# Correlation Coefficient for CatBoost with HyperbandPruner: 0.9489559729651481
# Running Optuna for CatBoost with ThresholdPruner...
# Best MSE for CatBoost with ThresholdPruner: 630.5453803317046 with params: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 64, 'min_data_in_leaf': 5, 'rsm': 1.0, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with ThresholdPruner: 25.11066268205012
# Correlation Coefficient for CatBoost with ThresholdPruner: 0.9489600108379744
# Running Optuna for CatBoost with WilcoxonPruner...
# Best MSE for CatBoost with WilcoxonPruner: 643.9058681801139 with params: {'iterations': 500, 'learning_rate': 0.03, 'depth': 4, 'l2_leaf_reg': 1, 'border_count': 32, 'min_data_in_leaf': 10, 'rsm': 1.0, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with WilcoxonPruner: 25.37530035645123
# Correlation Coefficient for CatBoost with WilcoxonPruner: 0.9524961757264667
# Running Optuna for NGBoost with MedianPruner...
# Best MSE for NGBoost with MedianPruner: 764.4986435785781 with params: {'n_estimators': 1000, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.9, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with MedianPruner: 27.649568596608848
# Correlation Coefficient for NGBoost with MedianPruner: 0.947510164485886
# Running Optuna for NGBoost with NopPruner...
# Best MSE for NGBoost with NopPruner: 686.5311122296366 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with NopPruner: 26.201738725314332
# Correlation Coefficient for NGBoost with NopPruner: 0.9534813869482387
# Running Optuna for NGBoost with PatientPruner...
# Best MSE for NGBoost with PatientPruner: 715.6082889546088 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.5, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PatientPruner: 26.750855854619097
# Correlation Coefficient for NGBoost with PatientPruner: 0.9459334028686258
# Running Optuna for NGBoost with PercentilePruner...
# Best MSE for NGBoost with PercentilePruner: 740.7984013307014 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.9, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PercentilePruner: 27.217611969654893
# Correlation Coefficient for NGBoost with PercentilePruner: 0.9506774767076946
# Running Optuna for NGBoost with SuccessiveHalvingPruner...
# Best MSE for NGBoost with SuccessiveHalvingPruner: 638.6888742760665 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with SuccessiveHalvingPruner: 25.272294598553305
# Correlation Coefficient for NGBoost with SuccessiveHalvingPruner: 0.9572337292952867
# Running Optuna for NGBoost with HyperbandPruner...
# Best MSE for NGBoost with HyperbandPruner: 697.6608917411146 with params: {'n_estimators': 1000, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with HyperbandPruner: 26.41327112913345
# Correlation Coefficient for NGBoost with HyperbandPruner: 0.9529991580886127
# Running Optuna for NGBoost with ThresholdPruner...
# Best MSE for NGBoost with ThresholdPruner: 821.8842540030902 with params: {'n_estimators': 1000, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.5, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with ThresholdPruner: 28.668523749978654
# Correlation Coefficient for NGBoost with ThresholdPruner: 0.9381593157350548
# Running Optuna for NGBoost with WilcoxonPruner...
# Best MSE for NGBoost with WilcoxonPruner: 616.7907109047201 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.5, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with WilcoxonPruner: 24.835271508576668
# Correlation Coefficient for NGBoost with WilcoxonPruner: 0.952055022204666
# Running Optuna for HistGradientBoosting with MedianPruner...
# Best MSE for HistGradientBoosting with MedianPruner: 894.3602762161045 with params: {'learning_rate': 0.1, 'max_iter': 500, 'max_depth': 7, 'min_samples_leaf': 20, 'max_leaf_nodes': None, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with MedianPruner: 29.90585688817668
# Correlation Coefficient for HistGradientBoosting with MedianPruner: 0.9273930905581117
# Running Optuna for HistGradientBoosting with NopPruner...
# Best MSE for HistGradientBoosting with NopPruner: 972.4158187613582 with params: {'learning_rate': 0.15, 'max_iter': 400, 'max_depth': None, 'min_samples_leaf': 5, 'max_leaf_nodes': 63, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': True, 'validation_fraction': 0.2, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with NopPruner: 31.183582519674648
# Correlation Coefficient for HistGradientBoosting with NopPruner: 0.9415278475522832
# Running Optuna for HistGradientBoosting with PatientPruner...
# Best MSE for HistGradientBoosting with PatientPruner: 895.4234055428822 with params: {'learning_rate': 0.1, 'max_iter': 400, 'max_depth': 7, 'min_samples_leaf': 20, 'max_leaf_nodes': 15, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PatientPruner: 29.92362620978417
# Correlation Coefficient for HistGradientBoosting with PatientPruner: 0.9270471460627402
# Running Optuna for HistGradientBoosting with PercentilePruner...
# Best MSE for HistGradientBoosting with PercentilePruner: 904.9606565486268 with params: {'learning_rate': 0.1, 'max_iter': 500, 'max_depth': 7, 'min_samples_leaf': 20, 'max_leaf_nodes': None, 'l2_regularization': 0.0, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PercentilePruner: 30.08256399558766
# Correlation Coefficient for HistGradientBoosting with PercentilePruner: 0.926980909291644
# Running Optuna for HistGradientBoosting with SuccessiveHalvingPruner...
# Best MSE for HistGradientBoosting with SuccessiveHalvingPruner: 890.0188862670979 with params: {'learning_rate': 0.1, 'max_iter': 400, 'max_depth': None, 'min_samples_leaf': 20, 'max_leaf_nodes': 31, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with SuccessiveHalvingPruner: 29.833184313229083
# Correlation Coefficient for HistGradientBoosting with SuccessiveHalvingPruner: 0.9272488132634422
# Running Optuna for HistGradientBoosting with HyperbandPruner...
# Best MSE for HistGradientBoosting with HyperbandPruner: 915.0251868729446 with params: {'learning_rate': 0.05, 'max_iter': 500, 'max_depth': 5, 'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'l2_regularization': 0.5, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with HyperbandPruner: 30.24938324781093
# Correlation Coefficient for HistGradientBoosting with HyperbandPruner: 0.9240920652279543
# Running Optuna for HistGradientBoosting with ThresholdPruner...
# Best MSE for HistGradientBoosting with ThresholdPruner: 887.852870315111 with params: {'learning_rate': 0.1, 'max_iter': 500, 'max_depth': None, 'min_samples_leaf': 20, 'max_leaf_nodes': 15, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with ThresholdPruner: 29.796860074764773
# Correlation Coefficient for HistGradientBoosting with ThresholdPruner: 0.9275994694463101
# Running Optuna for HistGradientBoosting with WilcoxonPruner...
# Best MSE for HistGradientBoosting with WilcoxonPruner: 896.2660904969946 with params: {'learning_rate': 0.1, 'max_iter': 200, 'max_depth': 7, 'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'l2_regularization': 0.1, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with WilcoxonPruner: 29.937703494038995
# Correlation Coefficient for HistGradientBoosting with WilcoxonPruner: 0.9275452759804554
# Running Optuna for PGBM with MedianPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/500, Train metric: 75.3859
# Estimator 1/500, Train metric: 68.6061
# Estimator 2/500, Train metric: 62.5382
# Estimator 3/500, Train metric: 57.5813
# Estimator 4/500, Train metric: 53.0865
# Estimator 5/500, Train metric: 48.9136
# Estimator 6/500, Train metric: 45.1505
# Estimator 7/500, Train metric: 42.7811
# Estimator 8/500, Train metric: 40.5681
# Estimator 9/500, Train metric: 38.3200
# Estimator 10/500, Train metric: 36.0123
# Estimator 11/500, Train metric: 33.4947
# Estimator 12/500, Train metric: 31.4008
# Estimator 13/500, Train metric: 29.6435
# Estimator 14/500, Train metric: 27.8629
# Estimator 15/500, Train metric: 25.9768
# Estimator 16/500, Train metric: 24.9108
# Estimator 17/500, Train metric: 23.8302
# Estimator 18/500, Train metric: 23.0561
# Estimator 19/500, Train metric: 21.9436
# Estimator 20/500, Train metric: 20.9398
# Estimator 21/500, Train metric: 19.9707
# Estimator 22/500, Train metric: 19.0122
# Estimator 23/500, Train metric: 18.2646
# Estimator 24/500, Train metric: 17.4688
# Estimator 25/500, Train metric: 16.5711
# Estimator 26/500, Train metric: 16.2585
# Estimator 27/500, Train metric: 15.2799
# Estimator 28/500, Train metric: 14.5724
# Estimator 29/500, Train metric: 14.1173
# Estimator 30/500, Train metric: 13.3253
# Estimator 31/500, Train metric: 12.8626
# Estimator 32/500, Train metric: 12.6102
# Estimator 33/500, Train metric: 12.1538
# Estimator 34/500, Train metric: 11.9752
# Estimator 35/500, Train metric: 11.5668
# Estimator 36/500, Train metric: 11.1180
# Estimator 37/500, Train metric: 10.7525
# Estimator 38/500, Train metric: 10.3328
# Estimator 39/500, Train metric: 10.0864
# Estimator 40/500, Train metric: 9.8951
# Estimator 41/500, Train metric: 9.6683
# Estimator 42/500, Train metric: 9.3791
# Estimator 43/500, Train metric: 9.1316
# Estimator 44/500, Train metric: 8.8094
# Estimator 45/500, Train metric: 8.5270
# Estimator 46/500, Train metric: 8.3108
# Estimator 47/500, Train metric: 8.2002
# Estimator 48/500, Train metric: 8.1375
# Estimator 49/500, Train metric: 7.9530
# Estimator 50/500, Train metric: 7.8874
# Estimator 51/500, Train metric: 7.6607
# Estimator 52/500, Train metric: 7.6103
# Estimator 53/500, Train metric: 7.5154
# Estimator 54/500, Train metric: 7.2818
# Estimator 55/500, Train metric: 7.1061
# Estimator 56/500, Train metric: 6.9119
# Estimator 57/500, Train metric: 6.6806
# Estimator 58/500, Train metric: 6.5294
# Estimator 59/500, Train metric: 6.5400
# Estimator 60/500, Train metric: 6.4270
# Estimator 61/500, Train metric: 6.2419
# Estimator 62/500, Train metric: 6.2093
# Estimator 63/500, Train metric: 6.0774
# Estimator 64/500, Train metric: 5.9011
# Estimator 65/500, Train metric: 5.7971
# Estimator 66/500, Train metric: 5.6552
# Estimator 67/500, Train metric: 5.5827
# Estimator 68/500, Train metric: 5.5581
# Estimator 69/500, Train metric: 5.5150
# Estimator 70/500, Train metric: 5.4429
# Estimator 71/500, Train metric: 5.4385
# Estimator 72/500, Train metric: 5.3284
# Estimator 73/500, Train metric: 5.2341
# Estimator 74/500, Train metric: 5.1943
# Estimator 75/500, Train metric: 5.0679
# Estimator 76/500, Train metric: 4.9534
# Estimator 77/500, Train metric: 4.7954
# Estimator 78/500, Train metric: 4.7018
# Estimator 79/500, Train metric: 4.5885
# Estimator 80/500, Train metric: 4.5436
# Estimator 81/500, Train metric: 4.4501
# Estimator 82/500, Train metric: 4.3901
# Estimator 83/500, Train metric: 4.3697
# Estimator 84/500, Train metric: 4.2764
# Estimator 85/500, Train metric: 4.2359
# Estimator 86/500, Train metric: 4.1594
# Estimator 87/500, Train metric: 4.1530
# Estimator 88/500, Train metric: 4.1155
# Estimator 89/500, Train metric: 4.0972
# Estimator 90/500, Train metric: 4.1039
# Estimator 91/500, Train metric: 4.0977
# Estimator 92/500, Train metric: 4.0548
# Estimator 93/500, Train metric: 4.0349
# Estimator 94/500, Train metric: 3.9496
# Estimator 95/500, Train metric: 3.8722
# Estimator 96/500, Train metric: 3.8752
# Estimator 97/500, Train metric: 3.8010
# Estimator 98/500, Train metric: 3.7887
# Estimator 99/500, Train metric: 3.7209
# Estimator 100/500, Train metric: 3.7243
# Estimator 101/500, Train metric: 3.6556
# Estimator 102/500, Train metric: 3.6573
# Estimator 103/500, Train metric: 3.5819
# Estimator 104/500, Train metric: 3.5521
# Estimator 105/500, Train metric: 3.4830
# Estimator 106/500, Train metric: 3.4744
# Estimator 107/500, Train metric: 3.4178
# Estimator 108/500, Train metric: 3.3851
# Estimator 109/500, Train metric: 3.3607
# Estimator 110/500, Train metric: 3.2808
# Estimator 111/500, Train metric: 3.2081
# Estimator 112/500, Train metric: 3.1443
# Estimator 113/500, Train metric: 3.0889
# Estimator 114/500, Train metric: 3.0317
# Estimator 115/500, Train metric: 2.9893
# Estimator 116/500, Train metric: 2.9210
# Estimator 117/500, Train metric: 2.9149
# Estimator 118/500, Train metric: 2.8739
# Estimator 119/500, Train metric: 2.8445
# Estimator 120/500, Train metric: 2.8448
# Estimator 121/500, Train metric: 2.8040
# Estimator 122/500, Train metric: 2.7589
# Estimator 123/500, Train metric: 2.7036
# Estimator 124/500, Train metric: 2.6963
# Estimator 125/500, Train metric: 2.6858
# Estimator 126/500, Train metric: 2.6530
# Estimator 127/500, Train metric: 2.6115
# Estimator 128/500, Train metric: 2.5644
# Estimator 129/500, Train metric: 2.5566
# Estimator 130/500, Train metric: 2.5301
# Estimator 131/500, Train metric: 2.4974
# Estimator 132/500, Train metric: 2.4475
# Estimator 133/500, Train metric: 2.4434
# Estimator 134/500, Train metric: 2.4197
# Estimator 135/500, Train metric: 2.4168
# Estimator 136/500, Train metric: 2.4143
# Estimator 137/500, Train metric: 2.3589
# Estimator 138/500, Train metric: 2.3524
# Estimator 139/500, Train metric: 2.3520
# Estimator 140/500, Train metric: 2.3572
# Estimator 141/500, Train metric: 2.3369
# Estimator 142/500, Train metric: 2.3349
# Estimator 143/500, Train metric: 2.3124
# Estimator 144/500, Train metric: 2.2931
# Estimator 145/500, Train metric: 2.2977
# Estimator 146/500, Train metric: 2.2712
# Estimator 147/500, Train metric: 2.2377
# Estimator 148/500, Train metric: 2.2404
# Estimator 149/500, Train metric: 2.2011
# Estimator 150/500, Train metric: 2.2049
# Estimator 151/500, Train metric: 2.2066
# Estimator 152/500, Train metric: 2.2116
# Estimator 153/500, Train metric: 2.1728
# Estimator 154/500, Train metric: 2.1511
# Estimator 155/500, Train metric: 2.1345
# Estimator 156/500, Train metric: 2.0930
# Estimator 157/500, Train metric: 2.0825
# Estimator 158/500, Train metric: 2.0377
# Estimator 159/500, Train metric: 2.0183
# Estimator 160/500, Train metric: 1.9822
# Estimator 161/500, Train metric: 1.9797
# Estimator 162/500, Train metric: 1.9764
# Estimator 163/500, Train metric: 1.9372
# Estimator 164/500, Train metric: 1.9175
# Estimator 165/500, Train metric: 1.9038
# Estimator 166/500, Train metric: 1.9011
# Estimator 167/500, Train metric: 1.8651
# Estimator 168/500, Train metric: 1.8391
# Estimator 169/500, Train metric: 1.8366
# Estimator 170/500, Train metric: 1.8355
# Estimator 171/500, Train metric: 1.8101
# Estimator 172/500, Train metric: 1.8085
# Estimator 173/500, Train metric: 1.7781
# Estimator 174/500, Train metric: 1.7777
# Estimator 175/500, Train metric: 1.7826
# Estimator 176/500, Train metric: 1.7665
# Estimator 177/500, Train metric: 1.7696
# Estimator 178/500, Train metric: 1.7731
# Estimator 179/500, Train metric: 1.7775
# Estimator 180/500, Train metric: 1.7777
# Estimator 181/500, Train metric: 1.7769
# Estimator 182/500, Train metric: 1.7786
# Estimator 183/500, Train metric: 1.7820
# Estimator 184/500, Train metric: 1.7496
# Estimator 185/500, Train metric: 1.7307
# Estimator 186/500, Train metric: 1.7337
# Estimator 187/500, Train metric: 1.7303
# Estimator 188/500, Train metric: 1.7118
# Estimator 189/500, Train metric: 1.7116
# Estimator 190/500, Train metric: 1.7146
# Estimator 191/500, Train metric: 1.7196
# Estimator 192/500, Train metric: 1.7201
# Estimator 193/500, Train metric: 1.7238
# Estimator 194/500, Train metric: 1.7230
# Estimator 195/500, Train metric: 1.7028
# Estimator 196/500, Train metric: 1.7071
# Estimator 197/500, Train metric: 1.6882
# Estimator 198/500, Train metric: 1.6732
# Estimator 199/500, Train metric: 1.6444
# Estimator 200/500, Train metric: 1.6452
# Estimator 201/500, Train metric: 1.6295
# Estimator 202/500, Train metric: 1.6297
# Estimator 203/500, Train metric: 1.6190
# Estimator 204/500, Train metric: 1.6091
# Estimator 205/500, Train metric: 1.5830
# Estimator 206/500, Train metric: 1.5833
# Estimator 207/500, Train metric: 1.5544
# Estimator 208/500, Train metric: 1.5275
# Estimator 209/500, Train metric: 1.5051
# Estimator 210/500, Train metric: 1.5100
# Estimator 211/500, Train metric: 1.5138
# Estimator 212/500, Train metric: 1.4912
# Estimator 213/500, Train metric: 1.4787
# Estimator 214/500, Train metric: 1.4767
# Estimator 215/500, Train metric: 1.4697
# Estimator 216/500, Train metric: 1.4719
# Estimator 217/500, Train metric: 1.4760
# Estimator 218/500, Train metric: 1.4545
# Estimator 219/500, Train metric: 1.4549
# Estimator 220/500, Train metric: 1.4575
# Estimator 221/500, Train metric: 1.4289
# Estimator 222/500, Train metric: 1.4307
# Estimator 223/500, Train metric: 1.4050
# Estimator 224/500, Train metric: 1.3808
# Estimator 225/500, Train metric: 1.3689
# Estimator 226/500, Train metric: 1.3687
# Estimator 227/500, Train metric: 1.3577
# Estimator 228/500, Train metric: 1.3294
# Estimator 229/500, Train metric: 1.3215
# Estimator 230/500, Train metric: 1.3212
# Estimator 231/500, Train metric: 1.3125
# Estimator 232/500, Train metric: 1.3113
# Estimator 233/500, Train metric: 1.3117
# Estimator 234/500, Train metric: 1.3110
# Estimator 235/500, Train metric: 1.3139
# Estimator 236/500, Train metric: 1.3183
# Estimator 237/500, Train metric: 1.3015
# Estimator 238/500, Train metric: 1.2781
# Estimator 239/500, Train metric: 1.2787
# Estimator 240/500, Train metric: 1.2813
# Estimator 241/500, Train metric: 1.2813
# Estimator 242/500, Train metric: 1.2820
# Estimator 243/500, Train metric: 1.2709
# Estimator 244/500, Train metric: 1.2611
# Estimator 245/500, Train metric: 1.2523
# Estimator 246/500, Train metric: 1.2304
# Estimator 247/500, Train metric: 1.2071
# Estimator 248/500, Train metric: 1.1991
# Estimator 249/500, Train metric: 1.1803
# Estimator 250/500, Train metric: 1.1738
# Estimator 251/500, Train metric: 1.1725
# Estimator 252/500, Train metric: 1.1513
# Estimator 253/500, Train metric: 1.1304
# Estimator 254/500, Train metric: 1.1136
# Estimator 255/500, Train metric: 1.1151
# Estimator 256/500, Train metric: 1.1159
# Estimator 257/500, Train metric: 1.0965
# Estimator 258/500, Train metric: 1.0765
# Estimator 259/500, Train metric: 1.0690
# Estimator 260/500, Train metric: 1.0710
# Estimator 261/500, Train metric: 1.0512
# Estimator 262/500, Train metric: 1.0425
# Estimator 263/500, Train metric: 1.0254
# Estimator 264/500, Train metric: 1.0275
# Estimator 265/500, Train metric: 1.0107
# Estimator 266/500, Train metric: 1.0132
# Estimator 267/500, Train metric: 0.9951
# Estimator 268/500, Train metric: 0.9977
# Estimator 269/500, Train metric: 0.9809
# Estimator 270/500, Train metric: 0.9746
# Estimator 271/500, Train metric: 0.9570
# ...
# Estimator 125/500, Train metric: 1.0965
# Estimator 126/500, Train metric: 1.0873
# Estimator 127/500, Train metric: 1.0890
# Estimator 128/500, Train metric: 1.0517
# Estimator 129/500, Train metric: 1.0494
# Estimator 130/500, Train metric: 1.0442
# Estimator 131/500, Train metric: 1.0494
# Estimator 132/500, Train metric: 1.0073
# Estimator 133/500, Train metric: 0.9999
# Estimator 134/500, Train metric: 0.9931
# Estimator 135/500, Train metric: 0.9666
# Estimator 136/500, Train metric: 0.9597
# Estimator 137/500, Train metric: 0.9266
# Estimator 138/500, Train metric: 0.9246
# Estimator 139/500, Train metric: 0.9224
# Estimator 140/500, Train metric: 0.9205
# Estimator 141/500, Train metric: 0.9212
# Estimator 142/500, Train metric: 0.9170
# Estimator 143/500, Train metric: 0.9134
# Estimator 144/500, Train metric: 0.8962
# Estimator 145/500, Train metric: 0.8954
# Estimator 146/500, Train metric: 0.8756
# Estimator 147/500, Train metric: 0.8504
# Estimator 148/500, Train metric: 0.8485
# Estimator 149/500, Train metric: 0.8216
# Estimator 150/500, Train metric: 0.8257
# Estimator 151/500, Train metric: 0.8261
# Estimator 152/500, Train metric: 0.8243
# Estimator 153/500, Train metric: 0.7971
# Estimator 154/500, Train metric: 0.7911
# Estimator 155/500, Train metric: 0.7867
# Estimator 156/500, Train metric: 0.7603
# Estimator 157/500, Train metric: 0.7552
# Estimator 158/500, Train metric: 0.7302
# Estimator 159/500, Train metric: 0.7293
# Estimator 160/500, Train metric: 0.6995
# Estimator 161/500, Train metric: 0.6841
# Estimator 162/500, Train metric: 0.6847
# Estimator 163/500, Train metric: 0.6631
# Estimator 164/500, Train metric: 0.6524
# Estimator 165/500, Train metric: 0.6513
# Estimator 166/500, Train metric: 0.6491
# Estimator 167/500, Train metric: 0.6263
# Estimator 168/500, Train metric: 0.6055
# Estimator 169/500, Train metric: 0.6022
# Estimator 170/500, Train metric: 0.5983
# Estimator 171/500, Train metric: 0.5989
# Estimator 172/500, Train metric: 0.5958
# Estimator 173/500, Train metric: 0.5777
# Estimator 174/500, Train metric: 0.5755
# Estimator 175/500, Train metric: 0.5635
# Estimator 176/500, Train metric: 0.5601
# Estimator 177/500, Train metric: 0.5569
# Estimator 178/500, Train metric: 0.5564
# Estimator 179/500, Train metric: 0.5576
# Estimator 180/500, Train metric: 0.5478
# Estimator 181/500, Train metric: 0.5453
# Estimator 182/500, Train metric: 0.5423
# Estimator 183/500, Train metric: 0.5426
# Estimator 184/500, Train metric: 0.5211
# Estimator 185/500, Train metric: 0.5182
# Estimator 186/500, Train metric: 0.5095
# Estimator 187/500, Train metric: 0.5094
# Estimator 188/500, Train metric: 0.5046
# Estimator 189/500, Train metric: 0.5029
# Estimator 190/500, Train metric: 0.5053
# Estimator 191/500, Train metric: 0.5047
# Estimator 192/500, Train metric: 0.5034
# Estimator 193/500, Train metric: 0.5027
# Estimator 194/500, Train metric: 0.5000
# Estimator 195/500, Train metric: 0.4958
# Estimator 196/500, Train metric: 0.4884
# Estimator 197/500, Train metric: 0.4865
# Estimator 198/500, Train metric: 0.4868
# Estimator 199/500, Train metric: 0.4701
# Estimator 200/500, Train metric: 0.4697
# Estimator 201/500, Train metric: 0.4671
# Estimator 202/500, Train metric: 0.4661
# Estimator 203/500, Train metric: 0.4674
# Estimator 204/500, Train metric: 0.4584
# Estimator 205/500, Train metric: 0.4416
# Estimator 206/500, Train metric: 0.4317
# Estimator 207/500, Train metric: 0.4170
# Estimator 208/500, Train metric: 0.4048
# Estimator 209/500, Train metric: 0.4046
# Estimator 210/500, Train metric: 0.4020
# Estimator 211/500, Train metric: 0.3937
# Estimator 212/500, Train metric: 0.3835
# Estimator 213/500, Train metric: 0.3833
# Estimator 214/500, Train metric: 0.3831
# Estimator 215/500, Train metric: 0.3832
# Estimator 216/500, Train metric: 0.3803
# Estimator 217/500, Train metric: 0.3787
# Estimator 218/500, Train metric: 0.3659
# Estimator 219/500, Train metric: 0.3655
# Estimator 220/500, Train metric: 0.3639
# Estimator 221/500, Train metric: 0.3507
# Estimator 222/500, Train metric: 0.3492
# Estimator 223/500, Train metric: 0.3385
# Estimator 224/500, Train metric: 0.3265
# Estimator 225/500, Train metric: 0.3215
# Estimator 226/500, Train metric: 0.3194
# Estimator 227/500, Train metric: 0.3137
# Estimator 228/500, Train metric: 0.3023
# Estimator 229/500, Train metric: 0.3010
# Estimator 230/500, Train metric: 0.2996
# Estimator 231/500, Train metric: 0.2984
# Estimator 232/500, Train metric: 0.2967
# Estimator 233/500, Train metric: 0.2964
# Estimator 234/500, Train metric: 0.2940
# Estimator 235/500, Train metric: 0.2927
# Estimator 236/500, Train metric: 0.2926
# Estimator 237/500, Train metric: 0.2927
# Estimator 238/500, Train metric: 0.2823
# Estimator 239/500, Train metric: 0.2820
# Estimator 240/500, Train metric: 0.2810
# Estimator 241/500, Train metric: 0.2801
# Estimator 242/500, Train metric: 0.2795
# Estimator 243/500, Train metric: 0.2748
# Estimator 244/500, Train metric: 0.2752
# Estimator 245/500, Train metric: 0.2759
# Estimator 246/500, Train metric: 0.2665
# Estimator 247/500, Train metric: 0.2567
# Estimator 248/500, Train metric: 0.2533
# Estimator 249/500, Train metric: 0.2444
# Estimator 250/500, Train metric: 0.2447
# Estimator 251/500, Train metric: 0.2438
# Estimator 252/500, Train metric: 0.2364
# Estimator 253/500, Train metric: 0.2284
# Estimator 254/500, Train metric: 0.2293
# Estimator 255/500, Train metric: 0.2266
# Estimator 256/500, Train metric: 0.2250
# Estimator 257/500, Train metric: 0.2184
# Estimator 258/500, Train metric: 0.2097
# Estimator 259/500, Train metric: 0.2048
# Estimator 260/500, Train metric: 0.2043
# Estimator 261/500, Train metric: 0.1955
# Estimator 262/500, Train metric: 0.1944
# Estimator 263/500, Train metric: 0.1880
# Estimator 264/500, Train metric: 0.1878
# Estimator 265/500, Train metric: 0.1812
# Estimator 266/500, Train metric: 0.1807
# Estimator 267/500, Train metric: 0.1752
# Estimator 268/500, Train metric: 0.1751
# Estimator 269/500, Train metric: 0.1684
# Estimator 270/500, Train metric: 0.1677
# Estimator 271/500, Train metric: 0.1622
# Estimator 272/500, Train metric: 0.1567
# Estimator 273/500, Train metric: 0.1503
# Estimator 274/500, Train metric: 0.1491
# Estimator 275/500, Train metric: 0.1439
# Estimator 276/500, Train metric: 0.1384
# Estimator 277/500, Train metric: 0.1342
# Estimator 278/500, Train metric: 0.1300
# Estimator 279/500, Train metric: 0.1294
# Estimator 280/500, Train metric: 0.1254
# Estimator 281/500, Train metric: 0.1250
# Estimator 282/500, Train metric: 0.1251
# Estimator 283/500, Train metric: 0.1257
# Estimator 284/500, Train metric: 0.1244
# Estimator 285/500, Train metric: 0.1199
# Estimator 286/500, Train metric: 0.1204
# Estimator 287/500, Train metric: 0.1188
# Estimator 288/500, Train metric: 0.1145
# Estimator 289/500, Train metric: 0.1106
# Estimator 290/500, Train metric: 0.1100
# Estimator 291/500, Train metric: 0.1082
# Estimator 292/500, Train metric: 0.1091
# Estimator 293/500, Train metric: 0.1075
# Estimator 294/500, Train metric: 0.1075
# Estimator 295/500, Train metric: 0.1038
# Estimator 296/500, Train metric: 0.1037
# Estimator 297/500, Train metric: 0.1001
# Estimator 298/500, Train metric: 0.0987
# Estimator 299/500, Train metric: 0.0987
# Estimator 300/500, Train metric: 0.0968
# Estimator 301/500, Train metric: 0.0931
# Estimator 302/500, Train metric: 0.0927
# Estimator 303/500, Train metric: 0.0930
# Estimator 304/500, Train metric: 0.0913
# Estimator 305/500, Train metric: 0.0901
# Estimator 306/500, Train metric: 0.0875
# Estimator 307/500, Train metric: 0.0869
# Estimator 308/500, Train metric: 0.0865
# Estimator 309/500, Train metric: 0.0833
# Estimator 310/500, Train metric: 0.0832
# Estimator 311/500, Train metric: 0.0824
# Estimator 312/500, Train metric: 0.0825
# Estimator 313/500, Train metric: 0.0799
# Estimator 314/500, Train metric: 0.0799
# Estimator 315/500, Train metric: 0.0802
# Estimator 316/500, Train metric: 0.0795
# Estimator 317/500, Train metric: 0.0800
# Estimator 318/500, Train metric: 0.0802
# Estimator 319/500, Train metric: 0.0773
# Estimator 320/500, Train metric: 0.0750
# Estimator 321/500, Train metric: 0.0736
# Estimator 322/500, Train metric: 0.0737
# Estimator 323/500, Train metric: 0.0735
# Estimator 324/500, Train metric: 0.0721
# Estimator 325/500, Train metric: 0.0722
# Estimator 326/500, Train metric: 0.0726
# Estimator 327/500, Train metric: 0.0715
# Estimator 328/500, Train metric: 0.0720
# Estimator 329/500, Train metric: 0.0711
# Estimator 330/500, Train metric: 0.0689
# Estimator 331/500, Train metric: 0.0691
# Estimator 332/500, Train metric: 0.0690
# Estimator 333/500, Train metric: 0.0690
# Estimator 334/500, Train metric: 0.0682
# Estimator 335/500, Train metric: 0.0655
# Estimator 336/500, Train metric: 0.0650
# Estimator 337/500, Train metric: 0.0646
# Estimator 338/500, Train metric: 0.0622
# Estimator 339/500, Train metric: 0.0620
# Estimator 340/500, Train metric: 0.0599
# Estimator 341/500, Train metric: 0.0597
# Estimator 342/500, Train metric: 0.0575
# Estimator 343/500, Train metric: 0.0573
# Estimator 344/500, Train metric: 0.0572
# Estimator 345/500, Train metric: 0.0573
# Estimator 346/500, Train metric: 0.0577
# Estimator 347/500, Train metric: 0.0555
# Estimator 348/500, Train metric: 0.0553
# Estimator 349/500, Train metric: 0.0556
# Estimator 350/500, Train metric: 0.0549
# Estimator 351/500, Train metric: 0.0542
# Estimator 352/500, Train metric: 0.0540
# Estimator 353/500, Train metric: 0.0517
# Estimator 354/500, Train metric: 0.0517
# Estimator 355/500, Train metric: 0.0521
# Estimator 356/500, Train metric: 0.0514
# Estimator 357/500, Train metric: 0.0517
# Estimator 358/500, Train metric: 0.0497
# Estimator 359/500, Train metric: 0.0499
# Estimator 360/500, Train metric: 0.0481
# Estimator 361/500, Train metric: 0.0475
# Estimator 362/500, Train metric: 0.0476
# Estimator 363/500, Train metric: 0.0479
# Estimator 364/500, Train metric: 0.0478
# Estimator 365/500, Train metric: 0.0482
# Estimator 366/500, Train metric: 0.0480
# Estimator 367/500, Train metric: 0.0481
# Estimator 368/500, Train metric: 0.0465
# Estimator 369/500, Train metric: 0.0449
# Estimator 370/500, Train metric: 0.0449
# Estimator 371/500, Train metric: 0.0449
# Estimator 372/500, Train metric: 0.0435
# Estimator 373/500, Train metric: 0.0420
# Estimator 374/500, Train metric: 0.0420
# Estimator 375/500, Train metric: 0.0422
# Estimator 376/500, Train metric: 0.0412
# Estimator 377/500, Train metric: 0.0398
# Estimator 378/500, Train metric: 0.0397
# Estimator 379/500, Train metric: 0.0393
# Estimator 380/500, Train metric: 0.0394
# Estimator 381/500, Train metric: 0.0395
# Estimator 382/500, Train metric: 0.0397
# Estimator 383/500, Train metric: 0.0388
# Estimator 384/500, Train metric: 0.0391
# Estimator 385/500, Train metric: 0.0386
# Estimator 386/500, Train metric: 0.0378
# Estimator 387/500, Train metric: 0.0375
# Estimator 388/500, Train metric: 0.0374
# Estimator 389/500, Train metric: 0.0368
# Estimator 390/500, Train metric: 0.0367
# Estimator 391/500, Train metric: 0.0367
# Estimator 392/500, Train metric: 0.0361
# Estimator 393/500, Train metric: 0.0344
# Estimator 394/500, Train metric: 0.0331
# Estimator 395/500, Train metric: 0.0324
# Estimator 396/500, Train metric: 0.0315
# Estimator 397/500, Train metric: 0.0308
# Estimator 398/500, Train metric: 0.0307
# Estimator 399/500, Train metric: 0.0301
# Estimator 400/500, Train metric: 0.0296
# Estimator 401/500, Train metric: 0.0295
# Estimator 402/500, Train metric: 0.0282
# Estimator 403/500, Train metric: 0.0282
# Estimator 404/500, Train metric: 0.0282
# Estimator 405/500, Train metric: 0.0277
# Estimator 406/500, Train metric: 0.0275
# Estimator 407/500, Train metric: 0.0260
# Estimator 408/500, Train metric: 0.0258
# Estimator 409/500, Train metric: 0.0257
# Estimator 410/500, Train metric: 0.0257
# Estimator 411/500, Train metric: 0.0254
# Estimator 412/500, Train metric: 0.0242
# Estimator 413/500, Train metric: 0.0239
# Estimator 414/500, Train metric: 0.0236
# Estimator 415/500, Train metric: 0.0235
# Estimator 416/500, Train metric: 0.0225
# Estimator 417/500, Train metric: 0.0224
# Estimator 418/500, Train metric: 0.0223
# Estimator 419/500, Train metric: 0.0223
# Estimator 420/500, Train metric: 0.0216
# Estimator 421/500, Train metric: 0.0216
# Estimator 422/500, Train metric: 0.0216
# Estimator 423/500, Train metric: 0.0217
# Estimator 424/500, Train metric: 0.0215
# Estimator 425/500, Train metric: 0.0214
# Estimator 426/500, Train metric: 0.0213
# Estimator 427/500, Train metric: 0.0212
# Estimator 428/500, Train metric: 0.0211
# Estimator 429/500, Train metric: 0.0210
# Estimator 430/500, Train metric: 0.0203
# Estimator 431/500, Train metric: 0.0198
# Estimator 432/500, Train metric: 0.0197
# Estimator 433/500, Train metric: 0.0194
# Estimator 434/500, Train metric: 0.0192
# Estimator 435/500, Train metric: 0.0191
# Estimator 436/500, Train metric: 0.0191
# Estimator 437/500, Train metric: 0.0191
# Estimator 438/500, Train metric: 0.0191
# Estimator 439/500, Train metric: 0.0192
# Estimator 440/500, Train metric: 0.0187
# Estimator 441/500, Train metric: 0.0188
# Estimator 442/500, Train metric: 0.0188
# Estimator 443/500, Train metric: 0.0190
# Estimator 444/500, Train metric: 0.0191
# Estimator 445/500, Train metric: 0.0185
# Estimator 446/500, Train metric: 0.0181
# Estimator 447/500, Train metric: 0.0177
# Estimator 448/500, Train metric: 0.0178
# Estimator 449/500, Train metric: 0.0173
# Estimator 450/500, Train metric: 0.0167
# Estimator 451/500, Train metric: 0.0163
# Estimator 452/500, Train metric: 0.0164
# Estimator 453/500, Train metric: 0.0161
# Estimator 454/500, Train metric: 0.0161
# Estimator 455/500, Train metric: 0.0162
# Estimator 456/500, Train metric: 0.0157
# Estimator 457/500, Train metric: 0.0157
# Estimator 458/500, Train metric: 0.0158
# Estimator 459/500, Train metric: 0.0158
# Estimator 460/500, Train metric: 0.0155
# Estimator 461/500, Train metric: 0.0153
# Estimator 462/500, Train metric: 0.0150
# Estimator 463/500, Train metric: 0.0147
# Estimator 464/500, Train metric: 0.0145
# Estimator 465/500, Train metric: 0.0142
# Estimator 466/500, Train metric: 0.0142
# Estimator 467/500, Train metric: 0.0138
# Estimator 468/500, Train metric: 0.0136
# Estimator 469/500, Train metric: 0.0137
# Estimator 470/500, Train metric: 0.0138
# Estimator 471/500, Train metric: 0.0140
# Estimator 472/500, Train metric: 0.0134
# Estimator 473/500, Train metric: 0.0132
# Estimator 474/500, Train metric: 0.0132
# Estimator 475/500, Train metric: 0.0131
# Estimator 476/500, Train metric: 0.0129
# Estimator 477/500, Train metric: 0.0130
# Estimator 478/500, Train metric: 0.0129
# Estimator 479/500, Train metric: 0.0128
# Estimator 480/500, Train metric: 0.0129
# Estimator 481/500, Train metric: 0.0127
# Estimator 482/500, Train metric: 0.0129
# Estimator 483/500, Train metric: 0.0127
# Estimator 484/500, Train metric: 0.0125
# Estimator 485/500, Train metric: 0.0124
# Estimator 486/500, Train metric: 0.0124
# Estimator 487/500, Train metric: 0.0123
# Estimator 488/500, Train metric: 0.0123
# Estimator 489/500, Train metric: 0.0121
# Estimator 490/500, Train metric: 0.0116
# Estimator 491/500, Train metric: 0.0111
# Estimator 492/500, Train metric: 0.0111
# Estimator 493/500, Train metric: 0.0111
# Estimator 494/500, Train metric: 0.0111
# Estimator 495/500, Train metric: 0.0112
# Estimator 496/500, Train metric: 0.0111
# Estimator 497/500, Train metric: 0.0112
# Estimator 498/500, Train metric: 0.0110
# Estimator 499/500, Train metric: 0.0109
# Best MSE for PGBM with WilcoxonPruner: 642.213251614053 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_leaves': 49, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.0, 'min_data_in_leaf': 3, 'max_bin': 64, 'distribution': 'laplace'}
# Best RMSE for PGBM with WilcoxonPruner: 25.341926754176626
# Correlation Coefficient for PGBM with WilcoxonPruner: 0.949001337869504
#
# Best model on test data: LightGBM with SuccessiveHalvingPruner
# Test MSE: 587.9233862763272
# Test RMSE: 24.247131506145777
# Correlation Coefficient: 0.9577393597234097
# Best Parameters: {'n_estimators': 400, 'learning_rate': 0.1, 'num_leaves': 15, 'max_depth': 5, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Pruner Used: SuccessiveHalvingPruner

# %%
best_scores_autosampler
# Out:
# {('Random Forest', 'MedianPruner'): {'best_score': 926.9746881386717,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'squared_error',
#    'max_depth': 20,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.5,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 926.9746881386717,
#   'test_rmse': 30.446259017138242,
#   'test_corr_coef': 0.9380539187700511,
#   'pruner': 'MedianPruner'},
#  ('Random Forest', 'NopPruner'): {'best_score': 937.9560207935197,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'squared_error',
#    'max_depth': 20,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 937.9560207935197,
#   'test_rmse': 30.62606766781396,
#   'test_corr_coef': 0.9338201932833533,
#   'pruner': 'NopPruner'},
#  ('Random Forest', 'PatientPruner'): {'best_score': 928.3935142510413,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'squared_error',
#    'max_depth': 30,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 928.3935142510413,
#   'test_rmse': 30.469550607960095,
#   'test_corr_coef': 0.9318269362838447,
#   'pruner': 'PatientPruner'},
#  ('Random Forest', 'PercentilePruner'): {'best_score': 936.3276968392234,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'friedman_mse',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 936.3276968392234,
#   'test_rmse': 30.599472166023116,
#   'test_corr_coef': 0.9443155093176682,
#   'pruner': 'PercentilePruner'},
#  ('Random Forest',
#   'SuccessiveHalvingPruner'): {'best_score': 922.9224466496914, 'best_params': {'n_estimators': 300,
#    'criterion': 'friedman_mse',
#    'max_depth': None,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01}, 'test_mse': 922.9224466496914, 'test_rmse': 30.379638685305185, 'test_corr_coef': 0.9344935993588843, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Random Forest', 'HyperbandPruner'): {'best_score': 928.6979037649045,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'squared_error',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.1},
#   'test_mse': 928.6979037649045,
#   'test_rmse': 30.474545177326345,
#   'test_corr_coef': 0.9305524100852461,
#   'pruner': 'HyperbandPruner'},
#  ('Random Forest', 'ThresholdPruner'): {'best_score': 929.8587794201471,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'squared_error',
#    'max_depth': 20,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01},
#   'test_mse': 929.8587794201471,
#   'test_rmse': 30.49358587342832,
#   'test_corr_coef': 0.930542178541985,
#   'pruner': 'ThresholdPruner'},
#  ('Random Forest', 'WilcoxonPruner'): {'best_score': 928.8038145612356,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.3,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.05},
#   'test_mse': 928.8038145612356,
#   'test_rmse': 30.476282820600606,
#   'test_corr_coef': 0.931846820097067,
#   'pruner': 'WilcoxonPruner'},
#  ('Gradient Boosting', 'MedianPruner'): {'best_score': 826.8450802541028,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 100,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.1,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 826.8450802541028,
#   'test_rmse': 28.754914019243785,
#   'test_corr_coef': 0.9279449171502246,
#   'pruner': 'MedianPruner'},
#  ('Gradient Boosting', 'NopPruner'): {'best_score': 781.7895087976207,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 700,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 781.7895087976207,
#   'test_rmse': 27.96049907990951,
#   'test_corr_coef': 0.9341384925660862,
#   'pruner': 'NopPruner'},
#  ('Gradient Boosting', 'PatientPruner'): {'best_score': 668.5962917226813,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 700,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 668.5962917226813,
#   'test_rmse': 25.857229003175906,
#   'test_corr_coef': 0.9420302992631479,
#   'pruner': 'PatientPruner'},
#  ('Gradient Boosting', 'PercentilePruner'): {'best_score': 696.7060074905164,
#   'best_params': {'loss': 'huber',
#    'learning_rate': 0.2,
#    'n_estimators': 500,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.0},
#   'test_mse': 696.7060074905164,
#   'test_rmse': 26.395189097457067,
#   'test_corr_coef': 0.946479542303648,
#   'pruner': 'PercentilePruner'},
#  ('Gradient Boosting',
#   'SuccessiveHalvingPruner'): {'best_score': 771.7055331834227, 'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.001}, 'test_mse': 771.7055331834227, 'test_rmse': 27.779588427178375, 'test_corr_coef': 0.9441148112370387, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Gradient Boosting', 'HyperbandPruner'): {'best_score': 702.5066063040902,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 500,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 10,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 50,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.01},
#   'test_mse': 702.5066063040902,
#   'test_rmse': 26.504841186169937,
#   'test_corr_coef': 0.9410771823195679,
#   'pruner': 'HyperbandPruner'},
#  ('Gradient Boosting', 'ThresholdPruner'): {'best_score': 716.4136543206561,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.2,
#    'n_estimators': 200,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.01},
#   'test_mse': 716.4136543206561,
#   'test_rmse': 26.765904698340687,
#   'test_corr_coef': 0.9402314074316714,
#   'pruner': 'ThresholdPruner'},
#  ('Gradient Boosting', 'WilcoxonPruner'): {'best_score': 727.7486334239142,
#   'best_params': {'loss': 'absolute_error',
#    'learning_rate': 0.1,
#    'n_estimators': 500,
#    'subsample': 1.0,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 'sqrt',
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 727.7486334239142,
#   'test_rmse': 26.976816591731392,
#   'test_corr_coef': 0.9360999910400127,
#   'pruner': 'WilcoxonPruner'},
#  ('XGBoost', 'MedianPruner'): {'best_score': 690.8297729492188,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 0.5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 690.8297729492188,
#   'test_rmse': 26.283640785652562,
#   'test_corr_coef': 0.9457246603165833,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 686.6576538085938,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'gamma': 0.5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 686.6576538085938,
#   'test_rmse': 26.204153369429697,
#   'test_corr_coef': 0.9497348647658967,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 622.8858642578125,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 0.5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 1,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 622.8858642578125,
#   'test_rmse': 24.957681467993226,
#   'test_corr_coef': 0.9526383255315664,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 605.669677734375,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'gamma': 0.1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 605.669677734375,
#   'test_rmse': 24.61035712325961,
#   'test_corr_coef': 0.9508572219911771,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 654.443603515625,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'min_child_weight': 5,
#    'gamma': 0.5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 10,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 654.443603515625,
#   'test_rmse': 25.58209536991888,
#   'test_corr_coef': 0.9481971540163014,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 664.0693359375,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 0.5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.5,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 664.0693359375,
#   'test_rmse': 25.769542796438976,
#   'test_corr_coef': 0.9473404883534584,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 687.9976806640625,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 687.9976806640625,
#   'test_rmse': 26.229709885243917,
#   'test_corr_coef': 0.9493622590036852,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 690.7450561523438,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 5,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 690.7450561523438,
#   'test_rmse': 26.28202914830481,
#   'test_corr_coef': 0.9434444285701333,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 687.6213685241634,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 687.6213685241634,
#   'test_rmse': 26.22253550906478,
#   'test_corr_coef': 0.9486948872823441,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 748.6190203392741,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 10,
#    'min_child_weight': 0.001,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 748.6190203392741,
#   'test_rmse': 27.360903134569117,
#   'test_corr_coef': 0.9450914571670231,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 707.208125570096,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 10,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 10,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 707.208125570096,
#   'test_rmse': 26.59338499646286,
#   'test_corr_coef': 0.9407200289406664,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 766.6062716200108,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'num_leaves': 63,
#    'max_depth': 5,
#    'min_child_samples': 20,
#    'subsample': 0.8,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 766.6062716200108,
#   'test_rmse': 27.687655581865556,
#   'test_corr_coef': 0.9345182922130101,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 587.9233862763272,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'num_leaves': 15,
#    'max_depth': 5,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 587.9233862763272,
#   'test_rmse': 24.247131506145777,
#   'test_corr_coef': 0.9577393597234097,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 598.7971005905614,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'num_leaves': 31,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 598.7971005905614,
#   'test_rmse': 24.470331027400537,
#   'test_corr_coef': 0.9562046162750685,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 673.6967643304616,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 10,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 673.6967643304616,
#   'test_rmse': 25.95566921368936,
#   'test_corr_coef': 0.9502168225063722,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 727.0376394439177,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': 7,
#    'min_child_samples': 20,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.01,
#    'bagging_freq': 0,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 727.0376394439177,
#   'test_rmse': 26.96363550124348,
#   'test_corr_coef': 0.9387415382908113,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 705.2209234493985,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 705.2209234493985,
#   'test_rmse': 26.555995998067903,
#   'test_corr_coef': 0.9409981493259966,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 701.3000437709593,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 701.3000437709593,
#   'test_rmse': 26.48207023196939,
#   'test_corr_coef': 0.9415580579884352,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 758.8116327218879,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'max_depth': 7,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.5,
#    'colsample_bytree': 0.5,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.1,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 758.8116327218879,
#   'test_rmse': 27.546535766260845,
#   'test_corr_coef': 0.935366184889031,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 749.6043356730718,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 5,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 749.6043356730718,
#   'test_rmse': 27.378903113037087,
#   'test_corr_coef': 0.9369245701596264,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 715.7122947830827,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'num_leaves': 63,
#    'min_child_samples': 20,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 715.7122947830827,
#   'test_rmse': 26.752799755971015,
#   'test_corr_coef': 0.9406035271489431,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 729.821365222223,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': -1,
#    'num_leaves': 31,
#    'min_child_samples': 20,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse':

#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 63,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 915.0251868729446,
#   'test_rmse': 30.24938324781093,
#   'test_corr_coef': 0.9240920652279543,
#   'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting', 'ThresholdPruner'): {'best_score': 887.852870315111,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 500,
#    'max_depth': None,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.1,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 887.852870315111,
#   'test_rmse': 29.796860074764773,
#   'test_corr_coef': 0.9275994694463101,
#   'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 896.2660904969946,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 200,
#    'max_depth': 7,
#    'min_samples_leaf': 20,
#    'max_leaf_nodes': 63,
#    'l2_regularization': 0.1,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 896.2660904969946,
#   'test_rmse': 29.937703494038995,
#   'test_corr_coef': 0.9275452759804554,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 611.1316919306154,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 24,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 611.1316919306154,
#   'test_rmse': 24.72107788771791,
#   'test_corr_coef': 0.9520618885844189,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 759.3681471811483,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_leaves': 22,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 759.3681471811483,
#   'test_rmse': 27.55663526595996,
#   'test_corr_coef': 0.9347099879037049,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 660.2953562214459,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_leaves': 51,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'studentt'},
#   'test_mse': 660.2953562214459,
#   'test_rmse': 25.696212877026177,
#   'test_corr_coef': 0.9508970849157568,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 704.9798058006301,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'max_leaves': 47,
#    'min_split_gain': 0.5,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 704.9798058006301,
#   'test_rmse': 26.551455813205987,
#   'test_corr_coef': 0.9485435469940052,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 743.2787056724476,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_leaves': 56,
#    'min_split_gain': 0.5,
#    'reg_lambda': 0.1,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 3,
#    'max_bin': 128,
#    'distribution': 'studentt'},
#   'test_mse': 743.2787056724476,
#   'test_rmse': 27.26313822127687,
#   'test_corr_coef': 0.9474862934724956,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 716.314319483747,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 42,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 716.314319483747,
#   'test_rmse': 26.764049011383666,
#   'test_corr_coef': 0.9496273048994742,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 614.4068909787804,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 41,
#    'min_split_gain': 0.0,
#    'reg_lambda': 5.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 614.4068909787804,
#   'test_rmse': 24.787232418702587,
#   'test_corr_coef': 0.951929563310526,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 642.213251614053,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_leaves': 49,
#    'min_split_gain': 0.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.0,
#    'min_data_in_leaf': 3,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 642.213251614053,
#   'test_rmse': 25.341926754176626,
#   'test_corr_coef': 0.949001337869504,
#   'pruner': 'WilcoxonPruner'}}

# %% [markdown]
# # **Best Model Analysis**

# %%
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        plt.savefig(plot_path)
        plt.close()

    # Save predictions and plots to Excel
    with pd.ExcelWriter(file_path.replace('.csv', '_results.xlsx'), engine='xlsxwriter') as writer:
        # Write data to Excel
        df.to_excel(writer, sheet_name='Data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            # Shorten the worksheet name to fit within Excel's 31 character limit
            short_model_name = ''.join([word[0] for word in model_name.split()])  # e.g., 'RF' for 'Random Forest'
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        os.remove(f'temp_plot_{model_name}.png')

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/WATER QUALITY/WQI_uncertainity/test.csv")
# Out:
# 0:	learn: 79.2768892	total: 29.5ms	remaining: 14.7s
# 1:	learn: 76.4930474	total: 113ms	remaining: 28.2s
# 2:	learn: 74.0251520	total: 126ms	remaining: 20.9s
# 3:	learn: 71.7932097	total: 145ms	remaining: 18s
# 4:	learn: 69.4646800	total: 169ms	remaining: 16.7s
# 5:	learn: 67.1695588	total: 182ms	remaining: 15s
# 6:	learn: 64.8958908	total: 190ms	remaining: 13.4s
# 7:	learn: 62.9166411	total: 199ms	remaining: 12.2s
# 8:	learn: 61.0462293	total: 206ms	remaining: 11.2s
# 9:	learn: 59.3372380	total: 214ms	remaining: 10.5s
# 10:	learn: 57.5536583	total: 221ms	remaining: 9.82s
# 11:	learn: 55.8841201	total: 232ms	remaining: 9.43s
# 12:	learn: 54.3103726	total: 239ms	remaining: 8.96s
# 13:	learn: 52.8855993	total: 247ms	remaining: 8.57s
# 14:	learn: 51.3956720	total: 254ms	remaining: 8.2s
# 15:	learn: 50.0154878	total: 261ms	remaining: 7.9s
# 16:	learn: 48.7873696	total: 269ms	remaining: 7.65s
# 17:	learn: 47.6215575	total: 277ms	remaining: 7.41s
# 492:	learn: 0.4172366	total: 4.13s	remaining: 58.7ms
# 493:	learn: 0.4134313	total: 4.14s	remaining: 50.3ms
# 494:	learn: 0.4118440	total: 4.15s	remaining: 41.9ms
# 495:	learn: 0.4091661	total: 4.16s	remaining: 33.5ms
# 496:	learn: 0.4074276	total: 4.16s	remaining: 25.1ms
# 497:	learn: 0.4034142	total: 4.17s	remaining: 16.7ms
# 498:	learn: 0.3996580	total: 4.18s	remaining: 8.37ms
# 499:	learn: 0.3979649	total: 4.18s	remaining: 0us
# Training on CPU
# Estimator 0/500, Train metric: 75.3859
# Estimator 1/500, Train metric: 68.6061
# Estimator 2/500, Train metric: 62.5382
# Estimator 3/500, Train metric: 57.5813
# Estimator 4/500, Train metric: 53.0865
# Estimator 5/500, Train metric: 48.9136
# Estimator 6/500, Train metric: 45.1505
# Estimator 7/500, Train metric: 42.7811
# Estimator 8/500, Train metric: 40.5681
# Estimator 9/500, Train metric: 38.3200
# Estimator 10/500, Train metric: 36.0123
# Estimator 11/500, Train metric: 33.4947
# Estimator 12/500, Train metric: 31.4008
# Estimator 13/500, Train metric: 29.6435
# Estimator 14/500, Train metric: 27.8629
# Estimator 15/500, Train metric: 25.9768
# Estimator 16/500, Train metric: 24.9108
# Estimator 17/500, Train metric: 23.8302
# Estimator 18/500, Train metric: 23.0561
# Estimator 19/500, Train metric: 21.9436
# Estimator 20/500, Train metric: 20.9398
# Estimator 21/500, Train metric: 19.9707
# Estimator 22/500, Train metric: 19.0122
# Estimator 23/500, Train metric: 18.2646
# Estimator 24/500, Train metric: 17.4688
# Estimator 25/500, Train metric: 16.5711
# Estimator 26/500, Train metric: 16.2585
# Estimator 27/500, Train metric: 15.2799
# Estimator 28/500, Train metric: 14.5724
# Estimator 29/500, Train metric: 14.1173
# Estimator 30/500, Train metric: 13.3253
# Estimator 31/500, Train metric: 12.8626
# Estimator 32/500, Train metric: 12.6102
# Estimator 33/500, Train metric: 12.1538
# Estimator 34/500, Train metric: 11.9752
# Estimator 35/500, Train metric: 11.5668
# Estimator 36/500, Train metric: 11.1180
# Estimator 37/500, Train metric: 10.7525
# Estimator 38/500, Train metric: 10.3328
# Estimator 39/500, Train metric: 10.0864
# Estimator 40/500, Train metric: 9.8951
# Estimator 41/500, Train metric: 9.6683
# Estimator 42/500, Train metric: 9.3791
# Estimator 43/500, Train metric: 9.1316
# Estimator 44/500, Train metric: 8.8094
# Estimator 45/500, Train metric: 8.5270
# Estimator 46/500, Train metric: 8.3108
# Estimator 47/500, Train metric: 8.2002
# Estimator 48/500, Train metric: 8.1375
# Estimator 49/500, Train metric: 7.9530
# Estimator 50/500, Train metric: 7.8874
# Estimator 51/500, Train metric: 7.6607
# Estimator 52/500, Train metric: 7.6103
# Estimator 53/500, Train metric: 7.5154
# Estimator 54/500, Train metric: 7.2818
# Estimator 55/500, Train metric: 7.1061
# Estimator 56/500, Train metric: 6.9119
# Estimator 57/500, Train metric: 6.6806
# Estimator 58/500, Train metric: 6.5294
# Estimator 59/500, Train metric: 6.5400
# Estimator 60/500, Train metric: 6.4270
# Estimator 61/500, Train metric: 6.2419
# Estimator 62/500, Train metric: 6.2093
# Estimator 63/500, Train metric: 6.0774
# Estimator 64/500, Train metric: 5.9011
# Estimator 65/500, Train metric: 5.7971
# Estimator 66/500, Train metric: 5.6552
# Estimator 67/500, Train metric: 5.5827
# Estimator 68/500, Train metric: 5.5581
# Estimator 69/500, Train metric: 5.5150
# Estimator 70/500, Train metric: 5.4429
# Estimator 71/500, Train metric: 5.4385
# Estimator 72/500, Train metric: 5.3284
# Estimator 73/500, Train metric: 5.2341
# Estimator 74/500, Train metric: 5.1943
# Estimator 75/500, Train metric: 5.0679
# Estimator 76/500, Train metric: 4.9534
# Estimator 77/500, Train metric: 4.7954
# Estimator 78/500, Train metric: 4.7018
# Estimator 79/500, Train metric: 4.5885
# Estimator 80/500, Train metric: 4.5436
# Estimator 81/500, Train metric: 4.4501
# Estimator 82/500, Train metric: 4.3901
# Estimator 83/500, Train metric: 4.3697
# Estimator 84/500, Train metric: 4.2764
# Estimator 85/500, Train metric: 4.2359
# Estimator 86/500, Train metric: 4.1594
# Estimator 87/500, Train metric: 4.1530
# Estimator 88/500, Train metric: 4.1155
# Estimator 89/500, Train metric: 4.0972
# Estimator 90/500, Train metric: 4.1039
# Estimator 91/500, Train metric: 4.0977
# Estimator 92/500, Train metric: 4.0548
# Estimator 93/500, Train metric: 4.0349
# Estimator 94/500, Train metric: 3.9496
# Estimator 95/500, Train metric: 3.8722
# Estimator 96/500, Train metric: 3.8752
# Estimator 97/500, Train metric: 3.8010
# Estimator 98/500, Train metric: 3.7887
# Estimator 99/500, Train metric: 3.7209
# Estimator 100/500, Train metric: 3.7243
# Estimator 101/500, Train metric: 3.6556
# Estimator 102/500, Train metric: 3.6573
# Estimator 103/500, Train metric: 3.5819
# Estimator 104/500, Train metric: 3.5521
# Estimator 105/500, Train metric: 3.4830
# Estimator 106/500, Train metric: 3.4744
# Estimator 107/500, Train metric: 3.4178
# Estimator 108/500, Train metric: 3.3851
# Estimator 109/500, Train metric: 3.3607
# Estimator 110/500, Train metric: 3.2808
# Estimator 111/500, Train metric: 3.2081
# Estimator 112/500, Train metric: 3.1443
# Estimator 113/500, Train metric: 3.0889
# Estimator 114/500, Train metric: 3.0317
# Estimator 115/500, Train metric: 2.9893
# Estimator 116/500, Train metric: 2.9210
# Estimator 117/500, Train metric: 2.9149
# Estimator 118/500, Train metric: 2.8739
# Estimator 119/500, Train metric: 2.8445
# Estimator 120/500, Train metric: 2.8448
# Estimator 121/500, Train metric: 2.8040
# Estimator 122/500, Train metric: 2.7589
# Estimator 123/500, Train metric: 2.7036
# Estimator 124/500, Train metric: 2.6963
# Estimator 125/500, Train metric: 2.6858
# Estimator 126/500, Train metric: 2.6530
# Estimator 127/500, Train metric: 2.6115
# Estimator 128/500, Train metric: 2.5644
# Estimator 129/500, Train metric: 2.5566
# Estimator 130/500, Train metric: 2.5301
# Estimator 131/500, Train metric: 2.4974
# Estimator 132/500, Train metric: 2.4475
# Estimator 133/500, Train metric: 2.4434
# Estimator 134/500, Train metric: 2.4197
# Estimator 135/500, Train metric: 2.4168
# Estimator 136/500, Train metric: 2.4143
# Estimator 137/500, Train metric: 2.3589
# Estimator 138/500, Train metric: 2.3524
# Estimator 139/500, Train metric: 2.3520
# Estimator 140/500, Train metric: 2.3572
# Estimator 141/500, Train metric: 2.3369
# Estimator 142/500, Train metric: 2.3349
# Estimator 143/500, Train metric: 2.3124
# Estimator 144/500, Train metric: 2.2931
# Estimator 145/500, Train metric: 2.2977
# Estimator 146/500, Train metric: 2.2712
# Estimator 147/500, Train metric: 2.2377
# Estimator 148/500, Train metric: 2.2404
# Estimator 149/500, Train metric: 2.2011
# Estimator 150/500, Train metric: 2.2049
# Estimator 151/500, Train metric: 2.2066
# Estimator 152/500, Train metric: 2.2116
# Estimator 153/500, Train metric: 2.1728
# Estimator 154/500, Train metric: 2.1511
# Estimator 155/500, Train metric: 2.1345
# Estimator 156/500, Train metric: 2.0930
# Estimator 157/500, Train metric: 2.0825
# Estimator 158/500, Train metric: 2.0377
# Estimator 159/500, Train metric: 2.0183
# Estimator 160/500, Train metric: 1.9822
# Estimator 161/500, Train metric: 1.9797
# Estimator 162/500, Train metric: 1.9764
# Estimator 163/500, Train metric: 1.9372
# Estimator 164/500, Train metric: 1.9175
# Estimator 165/500, Train metric: 1.9038
# Estimator 166/500, Train metric: 1.9011
# Estimator 167/500, Train metric: 1.8651
# Estimator 168/500, Train metric: 1.8391
# Estimator 169/500, Train metric: 1.8366
# Estimator 170/500, Train metric: 1.8355
# Estimator 171/500, Train metric: 1.8101
# Estimator 172/500, Train metric: 1.8085
# Estimator 173/500, Train metric: 1.7781
# Estimator 174/500, Train metric: 1.7777
# Estimator 175/500, Train metric: 1.7826
# Estimator 176/500, Train metric: 1.7665
# Estimator 177/500, Train metric: 1.7696
# Estimator 178/500, Train metric: 1.7731
# Estimator 179/500, Train metric: 1.7775
# Estimator 180/500, Train metric: 1.7777
# Estimator 181/500, Train metric: 1.7769
# Estimator 182/500, Train metric: 1.7786
# Estimator 183/500, Train metric: 1.7820
# Estimator 184/500, Train metric: 1.7496
# Estimator 185/500, Train metric: 1.7307
# Estimator 186/500, Train metric: 1.7337
# Estimator 187/500, Train metric: 1.7303
# Estimator 188/500, Train metric: 1.7118
# Estimator 189/500, Train metric: 1.7116
# Estimator 190/500, Train metric: 1.7146
# Estimator 191/500, Train metric: 1.7196
# Estimator 192/500, Train metric: 1.7201
# Estimator 193/500, Train metric: 1.7238
# Estimator 194/500, Train metric: 1.7230
# Estimator 195/500, Train metric: 1.7028
# Estimator 196/500, Train metric: 1.7071
# Estimator 197/500, Train metric: 1.6882
# Estimator 198/500, Train metric: 1.6732
# Estimator 199/500, Train metric: 1.6444
# Estimator 200/500, Train metric: 1.6452
# Estimator 201/500, Train metric: 1.6295
# Estimator 202/500, Train metric: 1.6297
# Estimator 203/500, Train metric: 1.6190
# Estimator 204/500, Train metric: 1.6091
# Estimator 205/500, Train metric: 1.5830
# Estimator 206/500, Train metric: 1.5833
# Estimator 207/500, Train metric: 1.5544
# Estimator 208/500, Train metric: 1.5275
# Estimator 209/500, Train metric: 1.5051
# Estimator 210/500, Train metric: 1.5100
# Estimator 211/500, Train metric: 1.5138
# Estimator 212/500, Train metric: 1.4912
# Estimator 213/500, Train metric: 1.4787
# Estimator 214/500, Train metric: 1.4767
# Estimator 215/500, Train metric: 1.4697
# Estimator 216/500, Train metric: 1.4719
# Estimator 217/500, Train metric: 1.4760
# Estimator 218/500, Train metric: 1.4545
# Estimator 219/500, Train metric: 1.4549
# Estimator 220/500, Train metric: 1.4575
# Estimator 221/500, Train metric: 1.4289
# Estimator 222/500, Train metric: 1.4307
# Estimator 223/500, Train metric: 1.4050
# Estimator 224/500, Train metric: 1.3808
# Estimator 225/500, Train metric: 1.3689
# Estimator 226/500, Train metric: 1.3687
# Estimator 227/500, Train metric: 1.3577
# Estimator 228/500, Train metric: 1.3294
# Estimator 229/500, Train metric: 1.3215
# Estimator 230/500, Train metric: 1.3212
# Estimator 231/500, Train metric: 1.3125
# Estimator 232/500, Train metric: 1.3113
# Estimator 233/500, Train metric: 1.3117
# Estimator 234/500, Train metric: 1.3110
# Estimator 235/500, Train metric: 1.3139
# Estimator 236/500, Train metric: 1.3183
# Estimator 237/500, Train metric: 1.3015
# Estimator 238/500, Train metric: 1.2781
# Estimator 239/500, Train metric: 1.2787
# Estimator 240/500, Train metric: 1.2813
# Estimator 241/500, Train metric: 1.2813
# Estimator 242/500, Train metric: 1.2820
# Estimator 243/500, Train metric: 1.2709
# Estimator 244/500, Train metric: 1.2611
# Estimator 245/500, Train metric: 1.2523
# Estimator 246/500, Train metric: 1.2304
# Estimator 247/500, Train metric: 1.2071
# Estimator 248/500, Train metric: 1.1991
# Estimator 249/500, Train metric: 1.1803
# Estimator 250/500, Train metric: 1.1738
# Estimator 251/500, Train metric: 1.1725
# Estimator 252/500, Train metric: 1.1513
# Estimator 253/500, Train metric: 1.1304
# Estimator 254/500, Train metric: 1.1136
# Estimator 255/500, Train metric: 1.1151
# Estimator 256/500, Train metric: 1.1159
# Estimator 257/500, Train metric: 1.0965
# Estimator 258/500, Train metric: 1.0765
# Estimator 259/500, Train metric: 1.0690
# Estimator 260/500, Train metric: 1.0710
# Estimator 261/500, Train metric: 1.0512
# Estimator 262/500, Train metric: 1.0425
# Estimator 263/500, Train metric: 1.0254
# Estimator 264/500, Train metric: 1.0275
# Estimator 265/500, Train metric: 1.0107
# Estimator 266/500, Train metric: 1.0132
# Estimator 267/500, Train metric: 0.9951
# Estimator 268/500, Train metric: 0.9977
# Estimator 269/500, Train metric: 0.9809
# Estimator 270/500, Train metric: 0.9746
# Estimator 271/500, Train metric: 0.9570
# Estimator 272/500, Train metric: 0.9399
# Estimator 273/500, Train metric: 0.9253
# Estimator 274/500, Train metric: 0.9207
# Estimator 275/500, Train metric: 0.9027
# Estimator 276/500, Train metric: 0.8854
# Estimator 277/500, Train metric: 0.8710
# Estimator 278/500, Train metric: 0.8557
# Estimator 279/500, Train metric: 0.8552
# Estimator 280/500, Train metric: 0.8406
# Estimator 281/500, Train metric: 0.8362
# Estimator 282/500, Train metric: 0.8308
# Estimator 283/500, Train metric: 0.8194
# Estimator 284/500, Train metric: 0.8194
# Estimator 285/500, Train metric: 0.8040
# Estimator 286/500, Train metric: 0.8004
# Estimator 287/500, Train metric: 0.7952
# Estimator 288/500, Train metric: 0.7856
# Estimator 289/500, Train metric: 0.7720
# Estimator 290/500, Train metric: 0.7712
# Estimator 291/500, Train metric: 0.7673
# Estimator 292/500, Train metric: 0.7591
# Estimator 293/500, Train metric: 0.7481
# Estimator 294/500, Train metric: 0.7477
# Estimator 295/500, Train metric: 0.7351
# Estimator 296/500, Train metric: 0.7266
# Estimator 297/500, Train metric: 0.7118
# Estimator 298/500, Train metric: 0.7085
# Estimator 299/500, Train metric: 0.6984
# Estimator 300/500, Train metric: 0.6976
# Estimator 301/500, Train metric: 0.6797
# Estimator 302/500, Train metric: 0.6797
# Estimator 303/500, Train metric: 0.6728
# Estimator 304/500, Train metric: 0.6712
# Estimator 305/500, Train metric: 0.6710
# Estimator 306/500, Train metric: 0.6595
# Estimator 307/500, Train metric: 0.6592
# Estimator 308/500, Train metric: 0.6581
# Estimator 309/500, Train metric: 0.6455
# Estimator 310/500, Train metric: 0.6411
# Estimator 311/500, Train metric: 0.6329
# Estimator 312/500, Train metric: 0.6296
# Estimator 313/500, Train metric: 0.6182
# Estimator 314/500, Train metric: 0.6149
# Estimator 315/500, Train metric: 0.6071
# Estimator 316/500, Train metric: 0.6060
# Estimator 317/500, Train metric: 0.6033
# Estimator 318/500, Train metric: 0.5996
# Estimator 319/500, Train metric: 0.5921
# Estimator 320/500, Train metric: 0.5822
# Estimator 321/500, Train metric: 0.5804
# Estimator 322/500, Train metric: 0.5802
# Estimator 323/500, Train metric: 0.5792
# Estimator 324/500, Train metric: 0.5788
# Estimator 325/500, Train metric: 0.5718
# Estimator 326/500, Train metric: 0.5702
# Estimator 327/500, Train metric: 0.5704
# Estimator 328/500, Train metric: 0.5687
# Estimator 329/500, Train metric: 0.5680
# Estimator 330/500, Train metric: 0.5580
# Estimator 331/500, Train metric: 0.5566
# Estimator 332/500, Train metric: 0.5554
# Estimator 333/500, Train metric: 0.5546
# Estimator 334/500, Train metric: 0.5550
# Estimator 335/500, Train metric: 0.5460
# Estimator 336/500, Train metric: 0.5455
# Estimator 337/500, Train metric: 0.5459
# Estimator 338/500, Train metric: 0.5365
# Estimator 339/500, Train metric: 0.5361
# Estimator 340/500, Train metric: 0.5257
# Estimator 341/500, Train metric: 0.5272
# Estimator 342/500, Train metric: 0.5186
# Estimator 343/500, Train metric: 0.5182
# Estimator 344/500, Train metric: 0.5182
# Estimator 345/500, Train metric: 0.5122
# Estimator 346/500, Train metric: 0.5101
# Estimator 347/500, Train metric: 0.5008
# Estimator 348/500, Train metric: 0.5009
# Estimator 349/500, Train metric: 0.4972
# Estimator 350/500, Train metric: 0.4913
# Estimator 351/500, Train metric: 0.4884
# Estimator 352/500, Train metric: 0.4883
# Estimator 353/500, Train metric: 0.4789
# Estimator 354/500, Train metric: 0.4789
# Estimator 355/500, Train metric: 0.4779
# Estimator 356/500, Train metric: 0.4775
# Estimator 357/500, Train metric: 0.4751
# Estimator 358/500, Train metric: 0.4659
# Estimator 359/500, Train metric: 0.4638
# Estimator 360/500, Train metric: 0.4547
# Estimator 361/500, Train metric: 0.4535
# Estimator 362/500, Train metric: 0.4528
# Estimator 363/500, Train metric: 0.4522
# Estimator 364/500, Train metric: 0.4519
# Estimator 365/500, Train metric: 0.4518
# Estimator 366/500, Train metric: 0.4508
# Estimator 367/500, Train metric: 0.4505
# Estimator 368/500, Train metric: 0.4420
# Estimator 369/500, Train metric: 0.4320
# Estimator 370/500, Train metric: 0.4312
# Estimator 371/500, Train metric: 0.4312
# Estimator 372/500, Train metric: 0.4222
# Estimator 373/500, Train metric: 0.4143
# Estimator 374/500, Train metric: 0.4142
# Estimator 375/500, Train metric: 0.4083
# Estimator 376/500, Train metric: 0.4008
# Estimator 377/500, Train metric: 0.3940
# Estimator 378/500, Train metric: 0.3934
# Estimator 379/500, Train metric: 0.3933
# Estimator 380/500, Train metric: 0.3921
# Estimator 381/500, Train metric: 0.3920
# Estimator 382/500, Train metric: 0.3918
# Estimator 383/500, Train metric: 0.3915
# Estimator 384/500, Train metric: 0.3873
# Estimator 385/500, Train metric: 0.3872
# Estimator 386/500, Train metric: 0.3874
# Estimator 387/500, Train metric: 0.3873
# Estimator 388/500, Train metric: 0.3870
# Estimator 389/500, Train metric: 0.3799
# Estimator 390/500, Train metric: 0.3806
# Estimator 391/500, Train metric: 0.3805
# Estimator 392/500, Train metric: 0.3814
# Estimator 393/500, Train metric: 0.3740
# Estimator 394/500, Train metric: 0.3677
# Estimator 395/500, Train metric: 0.3656
# Estimator 396/500, Train metric: 0.3591
# Estimator 397/500, Train metric: 0.3534
# Estimator 398/500, Train metric: 0.3531
# Estimator 399/500, Train metric: 0.3540
# Estimator 400/500, Train metric: 0.3550
# Estimator 401/500, Train metric: 0.3526
# Estimator 402/500, Train metric: 0.3468
# Estimator 403/500, Train metric: 0.3468
# Estimator 404/500, Train metric: 0.3477
# Estimator 405/500, Train metric: 0.3412
# Estimator 406/500, Train metric: 0.3417
# Estimator 407/500, Train metric: 0.3352
# Estimator 408/500, Train metric: 0.3348
# Estimator 409/500, Train metric: 0.3324
# Estimator 410/500, Train metric: 0.3332
# Estimator 411/500, Train metric: 0.3343
# Estimator 412/500, Train metric: 0.3283
# Estimator 413/500, Train metric: 0.3295
# Estimator 414/500, Train metric: 0.3306
# Estimator 415/500, Train metric: 0.3305
# Estimator 416/500, Train metric: 0.3247
# Estimator 417/500, Train metric: 0.3201
# Estimator 418/500, Train metric: 0.3210
# Estimator 419/500, Train metric: 0.3195
# Estimator 420/500, Train metric: 0.3139
# Estimator 421/500, Train metric: 0.3149
# Estimator 422/500, Train metric: 0.3154
# Estimator 423/500, Train metric: 0.3166
# Estimator 424/500, Train metric: 0.3144
# Estimator 425/500, Train metric: 0.3122
# Estimator 426/500, Train metric: 0.3125
# Estimator 427/500, Train metric: 0.3136
# Estimator 428/500, Train metric: 0.3134
# Estimator 429/500, Train metric: 0.3113
# Estimator 430/500, Train metric: 0.3058
# Estimator 431/500, Train metric: 0.3003
# Estimator 432/500, Train metric: 0.3001
# Estimator 433/500, Train metric: 0.2957
# Estimator 434/500, Train metric: 0.2936
# Estimator 435/500, Train metric: 0.2920
# Estimator 436/500, Train metric: 0.2908
# Estimator 437/500, Train metric: 0.2908
# Estimator 438/500, Train metric: 0.2909
# Estimator 439/500, Train metric: 0.2898
# Estimator 440/500, Train metric: 0.2897
# Estimator 441/500, Train metric: 0.2859
# Estimator 442/500, Train metric: 0.2856
# Estimator 443/500, Train metric: 0.2845
# Estimator 444/500, Train metric: 0.2831
# Estimator 445/500, Train metric: 0.2787
# Estimator 446/500, Train metric: 0.2741
# Estimator 447/500, Train metric: 0.2691
# Estimator 448/500, Train metric: 0.2653
# Estimator 449/500, Train metric: 0.2606
# Estimator 450/500, Train metric: 0.2556
# Estimator 451/500, Train metric: 0.2557
# Estimator 452/500, Train metric: 0.2556
# Estimator 453/500, Train metric: 0.2557
# Estimator 454/500, Train metric: 0.2559
# Estimator 455/500, Train metric: 0.2525
# Estimator 456/500, Train metric: 0.2493
# Estimator 457/500, Train metric: 0.2483
# Estimator 458/500, Train metric: 0.2447
# Estimator 459/500, Train metric: 0.2447
# Estimator 460/500, Train metric: 0.2446
# Estimator 461/500, Train metric: 0.2449
# Estimator 462/500, Train metric: 0.2450
# Estimator 463/500, Train metric: 0.2457
# Estimator 464/500, Train metric: 0.2410
# Estimator 465/500, Train metric: 0.2417
# Estimator 466/500, Train metric: 0.2423
# Estimator 467/500, Train metric: 0.2382
# Estimator 468/500, Train metric: 0.2391
# Estimator 469/500, Train metric: 0.2398
# Estimator 470/500, Train metric: 0.2403
# Estimator 471/500, Train metric: 0.2411
# Estimator 472/500, Train metric: 0.2418
# Estimator 473/500, Train metric: 0.2421
# Estimator 474/500, Train metric: 0.2419
# Estimator 475/500, Train metric: 0.2419
# Estimator 476/500, Train metric: 0.2376
# Estimator 477/500, Train metric: 0.2382
# Estimator 478/500, Train metric: 0.2378
# Estimator 479/500, Train metric: 0.2376
# Estimator 480/500, Train metric: 0.2385
# Estimator 481/500, Train metric: 0.2394
# Estimator 482/500, Train metric: 0.2404
# Estimator 483/500, Train metric: 0.2400
# Estimator 484/500, Train metric: 0.2378
# Estimator 485/500, Train metric: 0.2358
# Estimator 486/500, Train metric: 0.2357
# Estimator 487/500, Train metric: 0.2321
# Estimator 488/500, Train metric: 0.2322
# Estimator 489/500, Train metric: 0.2331
# Estimator 490/500, Train metric: 0.2288
# Estimator 491/500, Train metric: 0.2246
# Estimator 492/500, Train metric: 0.2247
# Estimator 493/500, Train metric: 0.2248
# Estimator 494/500, Train metric: 0.2246
# Estimator 495/500, Train metric: 0.2246
# Estimator 496/500, Train metric: 0.2253
# Estimator 497/500, Train metric: 0.2261
# Estimator 498/500, Train metric: 0.2221
# Estimator 499/500, Train metric: 0.2222

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/WATER QUALITY/WQI_uncertainity/WQI_ml/HyperParameter_Tuning/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/WATER QUALITY/WQI_uncertainity/WQI_ml/HyperParameter_Tuning/test_results.xlsx")
# Out:
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
# WARNING:shap:Using 190 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/82 [00:00<?, ?it/s]
